# %% [markdown]
# # Install libraries

# %%
import sys, os, json
import mne, sklearn, wandb
import numpy as np
import pandas as pd

from scipy.interpolate import interp1d
from nilearn import datasets, image, masking, plotting
from nilearn.input_data import NiftiLabelsMasker


# animation part
from IPython.display import HTML
import matplotlib
import matplotlib.pyplot as plt
# from celluloid import Camera   # it is convinient method to animate
from matplotlib import animation, rc
from matplotlib.animation import FuncAnimation


## torch libraries 
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader, Subset

from pytorch_model_summary import summary
# Out:
# /opt/conda/envs/myenv_torch/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.insert(1, os.path.realpath(os.path.pardir))

from utils import get_datasets
from utils import preproc
from utils import torch_dataset
from utils import train_utils
from utils import inference
from utils.models_arch import autoencoder_new_Artur

# %% [markdown]
# # Set all hyperparameters
# - Cuda and GPU.
# - Parameters of dataset.
# - random seed( if necessary).

# %%
# import random

# torch.manual_seed(0)
# random.seed(0)  # python operation seed
# np.random.seed(0)

# torch.backends.cudnn.benchmark = False
# torch.backends.cudnn.deterministic = True

print(torch.cuda.is_available(), torch.cuda.device_count())
torch.cuda.set_device(0)
# Out:
# True 4

# %%
config = dict(  
                dataset_name = 'CWL_raw', # CWL
                patients = 'trio1',
                fps = 1000,
                new_fps=100, 
                crop_start = 5,
                freqs = [-1], 
    
                n_channels = 30, # 63 
                n_roi = 8,
                
                bold_delay = 6,
                to_many = True,
                random_subsample = True,
                sample_per_epoch = 512, 
                WINDOW_SIZE = 2048,
                    
                optimizer='adamW',
                lr=3e-4,
                weight_decay=3e-4, 
                batch_size=16, 
                    
                mse_weight = 1,
                corr_weight = 0,
                
                preproc_type = 'dB_log',
                loss_function = 'corr', 
                model_type = 'Best_AE_Artur_Multi_Head'
                )


hp_autoencoder = dict(n_electrodes=config['n_channels'],
                      n_freqs = len(config['freqs']),
                      n_channels_out = config['n_roi'],

                     channels = [128, 128, 128, 128], 
                     kernel_sizes=[5, 5, 3],
                     strides=[8, 8, 4], 
                     dilation=[1, 1, 1], 
                     decoder_reduce=4, 
                     hidden_channels = 16,
                     )


config = {**hp_autoencoder, **config}

params_train = {'batch_size': config['batch_size'],
                'shuffle': True,
                'num_workers': 0}

params_val = {'batch_size': config['batch_size'],
              'shuffle': False}

# %% [markdown]
# # Upload preprocessed dataset from np files.
# It should accelerate speed of experiments.

# %%
with open("../data/interim/labels_roi_17.json", 'r') as f:
    labels_roi_17 = json.load(f)
    
labels_roi = ['Left Pallidum',
                     'Left Caudate',
                     'Left Putamen',
                     'Left Accumbens',
                      
                     'Right Pallidum',
                     'Right Caudate',
                     'Right Putamen',
                     'Right Accumbens']

# %%
if config['dataset_name']=='CWL_raw':
    
    dataset_path = f"../data/interim/CWL/{config['patients']}_1000_filtered_data.npz"

elif config['dataset_name']=='NODDI_raw':
    dataset_path = '../data/interim/NODDI/32_250_filtered_data.npz'
else:
    print('no such dataset')



data = np.load(dataset_path)

eeg, fmri = data['eeg'], data['fmri']
df = pd.DataFrame(data = fmri.T, columns=labels_roi_17)
df_filter = df[labels_roi]
fmri = df_filter.to_numpy().T

# crop start
train_crop = config['crop_start']*config['fps']
eeg, fmri = eeg[..., train_crop:], fmri[..., train_crop:]

# normalize 
eeg = eeg / np.std(eeg)
fmri, fmri_means_stds = preproc.normalize_data(fmri)

# train/test split
test_time = int(60*config['fps'])
train_dataset_prep = (eeg[..., :-test_time], fmri[..., :-test_time])
test_dataset_prep = (eeg[..., -test_time:], fmri[..., -test_time:])


ds_factor = config['fps']/config['new_fps']
train_dataset_prep = preproc.downsample_dataset(train_dataset_prep, factor = ds_factor)
test_dataset_prep = preproc.downsample_dataset(test_dataset_prep, factor = ds_factor)





# apply time dealy corrected
train_dataset_prep = preproc.bold_time_delay_align(train_dataset_prep, 
                                                   config['new_fps'],
                                                   config['bold_delay'])
test_dataset_prep = preproc.bold_time_delay_align(test_dataset_prep, 
                                                  config['new_fps'],
                                                  config['bold_delay'])


print('Size of train dataset:', train_dataset_prep[0].shape, train_dataset_prep[1].shape)
print('Size of test dataset:', test_dataset_prep[0].shape, test_dataset_prep[1].shape)

# torch dataset creation 
torch_dataset_train = torch_dataset.CreateDataset_eeg_fmri(train_dataset_prep, 
                                                            random_sample=config['random_subsample'], 
                                                            sample_per_epoch=config['sample_per_epoch'], 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])

torch_dataset_test = torch_dataset.CreateDataset_eeg_fmri(test_dataset_prep, 
                                                            random_sample=False, 
                                                            sample_per_epoch=None, 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])
print(len(torch_dataset_test))
# because you do not have strid for val data. 
torch_dataset_test = Subset(torch_dataset_test, np.arange(len(torch_dataset_test))[::100])

# init dataloaders for training
train_loader = torch.utils.data.DataLoader(torch_dataset_train, **params_train)
val_loader = torch.utils.data.DataLoader(torch_dataset_test, **params_val)
# Out:
# Size of train dataset: (30, 20980) (8, 20980)
# Size of test dataset: (30, 5400) (8, 5400)
# 3351

# %% [markdown]
# # Init Model, Loss, optimizers

# %%
model = autoencoder_new_Artur.AutoEncoder1D_Artur_MultiHead(hp_autoencoder)

print(summary(model, torch.zeros(4, config['n_channels'],
                                 config['WINDOW_SIZE']), show_input=False))
# Out:
# -----------------------------------------------------------------------------
#             Layer (type)        Output Shape         Param #     Tr. Param #
# =============================================================================
#    AutoEncoder1D_Artur-1        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-2        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-3        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-4        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-5        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-6        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-7        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-8        [4, 1, 2048]         245,057         245,057
# =============================================================================
# Total params: 1,960,456
# Trainable params: 1,960,456
# Non-trainable params: 0
# -----------------------------------------------------------------------------

# %% [markdown]
# # Model training

# %%
n_runs = 3

for i in range(n_runs):
    
    model = autoencoder_new_Artur.AutoEncoder1D_Artur_MultiHead(hp_autoencoder)

    loss_func = train_utils.make_complex_loss_function(mse_weight = config['mse_weight'], 
                                                       corr_weight = config['corr_weight'],
                                                       manifold_weight = 0,
                                                       bound=1)
    train_step = train_utils.train_step

    optimizer = optim.AdamW(model.parameters(), 
                       lr=config['lr'], 
                       weight_decay=config['weight_decay'])
    
    
    parameters = {
        'EPOCHS': 1500,
        'model': model, 
        'train_loader': train_loader, 
        'val_loader': val_loader, 
        'loss_function': loss_func,
        'train_step': train_step,
        'optimizer': optimizer, 
        'device': 'cuda', 
        'raw_test_data': test_dataset_prep,
        'show_info': 20, 
        'num_losses': 5,
        'labels': labels_roi,
        'inference_function': inference.model_inference_function, 
        'to_many': config['to_many']
    }



    path_to_save_wandb = 'common/koval_alvi/Checkpoints/wandb_brain'
    
    
    with wandb.init(project="eeg_fmri", config=config, save_code=True):
        
        wandb.define_metric("val/corr_mean", summary="max")

        if i == 0: 
            exp_name = wandb.run.name
        
        wandb.run.name = exp_name +'_run_' + str(i)
        
        print(config)
        print(parameters['model'])
        print(summary(model, torch.zeros(4, config['n_channels'], config['WINDOW_SIZE']), show_input=False))
        
        model = train_utils.wanb_train_regression(**parameters)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: koval_alvi (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.13.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/6phq9380" target="_blank">vibrant-resonance-487</a></strong> to <a href="https://wandb.ai/koval_alvi/eeg_fmri" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# {'n_electrodes': 30, 'n_freqs': 1, 'n_channels_out': 8, 'channels': [128, 128, 128, 128], 'kernel_sizes': [5, 5, 3], 'strides': [8, 8, 4], 'dilation': [1, 1, 1], 'decoder_reduce': 4, 'hidden_channels': 16, 'dataset_name': 'CWL_raw', 'patients': 'trio2', 'fps': 1000, 'new_fps': 100, 'crop_start': 5, 'freqs': [-1], 'n_channels': 30, 'n_roi': 8, 'bold_delay': 6, 'to_many': True, 'random_subsample': True, 'sample_per_epoch': 512, 'WINDOW_SIZE': 2048, 'optimizer': 'adamW', 'lr': 0.0003, 'weight_decay': 0.0003, 'batch_size': 16, 'mse_weight': 1, 'corr_weight': 0, 'preproc_type': 'dB_log', 'loss_function': 'corr', 'model_type': 'Best_AE_Artur_Multi_Head'}
# AutoEncoder1D_Artur_MultiHead(
#   (models): ModuleList(
#     (0): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (1): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (2): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (3): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (4): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (5): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (6): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#     (7): AutoEncoder1D_Artur(
#       (artur_block): ArturBlock(
#         (unmixing_layer): Conv1d(30, 16, kernel_size=(1,), stride=(1,))
#         (unmixed_channels_batchnorm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (band_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16, bias=False)
#         (norm): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (act): ReLU()
#         (low_pass): Conv1d(16, 16, kernel_size=(51,), stride=(1,), padding=same, groups=16)
#       )
#       (spatial_reduce): ConvBlock(
#         (conv1d): Conv1d(16, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downsample_blocks): ModuleList(
#         (0): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (1): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#         )
#         (2): ConvBlock(
#           (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (activation): GELU()
#           (drop): Dropout(p=0.3, inplace=False)
#           (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#       (upsample_blocks): ModuleList(
#         (0): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=4.0, mode=linear)
#         )
#         (1): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#         (2): UpConvBlock(
#           (conv_block): ConvBlock(
#             (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#   )
# )
# -----------------------------------------------------------------------------
#             Layer (type)        Output Shape         Param #     Tr. Param #
# =============================================================================
#    AutoEncoder1D_Artur-1        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-2        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-3        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-4        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-5        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-6        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-7        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-8        [4, 1, 2048]         245,057         245,057
# =============================================================================
# Total params: 1,960,456
# Trainable params: 1,960,456
# Non-trainable params: 0
# -----------------------------------------------------------------------------
# Starting Training of our model
# Number of samples 512
# Size of batch: 16 Number batches 32
# ................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................(8, 5120)
# (8, 5120)
# ................................................................(8, 5120)
# (8, 5120)
# ................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................
# Epoch 20 train loss_0 : 0.488 val loss_0 : 2.24 train loss_1 : 0.496 val loss_1 : -0.0204 train loss_2 : 0.488 val loss_2 : 2.24 train loss_3 : 8.45 val loss_3 : 14.4
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 40 train loss_0 : 0.184 val loss_0 : 2.28 train loss_1 : 0.823 val loss_1 : 0.0543 train loss_2 : 0.184 val loss_2 : 2.28 train loss_3 : 4.46 val loss_3 : 8.78
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 60 train loss_0 : 0.12 val loss_0 : 2.23 train loss_1 : 0.885 val loss_1 : 0.0189 train loss_2 : 0.12 val loss_2 : 2.23 train loss_3 : 3.83 val loss_3 : 8.56
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 80 train loss_0 : 0.0917 val loss_0 : 2.07 train loss_1 : 0.905 val loss_1 : 0.0534 train loss_2 : 0.0917 val loss_2 : 2.07 train loss_3 : 3.69 val loss_3 : 8.73
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 100 train loss_0 : 0.0855 val loss_0 : 2.05 train loss_1 : 0.923 val loss_1 : 0.0571 train loss_2 : 0.0855 val loss_2 : 2.05 train loss_3 : 3.57 val loss_3 : 8.3
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 120 train loss_0 : 0.0733 val loss_0 : 2.02 train loss_1 : 0.925 val loss_1 : 0.0656 train loss_2 : 0.0733 val loss_2 : 2.02 train loss_3 : 3.52 val loss_3 : 8.35
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 140 train loss_0 : 0.0725 val loss_0 : 2.0 train loss_1 : 0.935 val loss_1 : 0.0739 train loss_2 : 0.0725 val loss_2 : 2.0 train loss_3 : 3.39 val loss_3 : 8.17
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 160 train loss_0 : 0.0664 val loss_0 : 2.08 train loss_1 : 0.938 val loss_1 : 0.0821 train loss_2 : 0.0664 val loss_2 : 2.08 train loss_3 : 3.37 val loss_3 : 8.14
# ................................................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 180 train loss_0 : 0.065 val loss_0 : 1.98 train loss_1 : 0.942 val loss_1 : 0.0861 train loss_2 : 0.065 val loss_2 : 1.98 train loss_3 : 3.28 val loss_3 : 8.26
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 200 train loss_0 : 0.0603 val loss_0 : 2.04 train loss_1 : 0.943 val loss_1 : 0.0549 train loss_2 : 0.0603 val loss_2 : 2.04 train loss_3 : 3.23 val loss_3 : 7.94
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 220 train loss_0 : 0.0593 val loss_0 : 2.02 train loss_1 : 0.946 val loss_1 : 0.111 train loss_2 : 0.0593 val loss_2 : 2.02 train loss_3 : 3.19 val loss_3 : 8.01
# ................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 240 train loss_0 : 0.0596 val loss_0 : 2.05 train loss_1 : 0.949 val loss_1 : 0.0774 train loss_2 : 0.0596 val loss_2 : 2.05 train loss_3 : 3.17 val loss_3 : 8.22
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 260 train loss_0 : 0.0572 val loss_0 : 2.09 train loss_1 : 0.95 val loss_1 : 0.0862 train loss_2 : 0.0572 val loss_2 : 2.09 train loss_3 : 3.08 val loss_3 : 8.29
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 280 train loss_0 : 0.0539 val loss_0 : 2.01 train loss_1 : 0.952 val loss_1 : 0.0955 train loss_2 : 0.0539 val loss_2 : 2.01 train loss_3 : 3.16 val loss_3 : 8.1
# ................................................................................................................................................................................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................
# Epoch 300 train loss_0 : 0.0497 val loss_0 : 2.02 train loss_1 : 0.952 val loss_1 : 0.104 train loss_2 : 0.0497 val loss_2 : 2.02 train loss_3 : 3.03 val loss_3 : 8.31
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 320 train loss_0 : 0.0506 val loss_0 : 2.06 train loss_1 : 0.954 val loss_1 : 0.0774 train loss_2 : 0.0506 val loss_2 : 2.06 train loss_3 : 3.08 val loss_3 : 8.15
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 340 train loss_0 : 0.0486 val loss_0 : 2.06 train loss_1 : 0.954 val loss_1 : 0.0879 train loss_2 : 0.0486 val loss_2 : 2.06 train loss_3 : 3.11 val loss_3 : 8.24
# ................................................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 360 train loss_0 : 0.0482 val loss_0 : 2.02 train loss_1 : 0.956 val loss_1 : 0.0843 train loss_2 : 0.0482 val loss_2 : 2.02 train loss_3 : 2.97 val loss_3 : 8.39
# ...
#             (activation): GELU()
#             (drop): Dropout(p=0.3, inplace=False)
#             (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#           )
#           (upsample): Upsample(scale_factor=8.0, mode=linear)
#         )
#       )
#       (conv1x1_one): Conv1d(32, 1, kernel_size=(1,), stride=(1,), padding=same)
#     )
#   )
# )
# -----------------------------------------------------------------------------
#             Layer (type)        Output Shape         Param #     Tr. Param #
# =============================================================================
#    AutoEncoder1D_Artur-1        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-2        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-3        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-4        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-5        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-6        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-7        [4, 1, 2048]         245,057         245,057
#    AutoEncoder1D_Artur-8        [4, 1, 2048]         245,057         245,057
# =============================================================================
# Total params: 1,960,456
# Trainable params: 1,960,456
# Non-trainable params: 0
# -----------------------------------------------------------------------------
# Starting Training of our model
# Number of samples 512
# Size of batch: 16 Number batches 32
# ................................(8, 5120)
# (8, 5120)
# ................................(8, 5120)
# (8, 5120)
# ................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................
# Epoch 20 train loss_0 : 0.757 val loss_0 : 2.01 train loss_1 : 0.246 val loss_1 : 0.0133 train loss_2 : 0.757 val loss_2 : 2.01 train loss_3 : 11.3 val loss_3 : 19.3
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................
# Epoch 40 train loss_0 : 0.345 val loss_0 : 2.08 train loss_1 : 0.635 val loss_1 : 0.0553 train loss_2 : 0.345 val loss_2 : 2.08 train loss_3 : 8.81 val loss_3 : 10.4
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 60 train loss_0 : 0.24 val loss_0 : 2.14 train loss_1 : 0.753 val loss_1 : 0.0313 train loss_2 : 0.24 val loss_2 : 2.14 train loss_3 : 8.6 val loss_3 : 9.61
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 100 train loss_0 : 0.196 val loss_0 : 2.13 train loss_1 : 0.798 val loss_1 : 0.0249 train loss_2 : 0.196 val loss_2 : 2.13 train loss_3 : 8.99 val loss_3 : 9.95
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 120 train loss_0 : 0.191 val loss_0 : 2.16 train loss_1 : 0.807 val loss_1 : -0.000301 train loss_2 : 0.191 val loss_2 : 2.16 train loss_3 : 9.28 val loss_3 : 10.2
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 140 train loss_0 : 0.192 val loss_0 : 2.11 train loss_1 : 0.813 val loss_1 : -0.00125 train loss_2 : 0.192 val loss_2 : 2.11 train loss_3 : 9.53 val loss_3 : 4.76
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 160 train loss_0 : 0.184 val loss_0 : 2.1 train loss_1 : 0.818 val loss_1 : -0.00602 train loss_2 : 0.184 val loss_2 : 2.1 train loss_3 : 9.74 val loss_3 : 5.34
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 180 train loss_0 : 0.175 val loss_0 : 2.13 train loss_1 : 0.82 val loss_1 : -0.0246 train loss_2 : 0.175 val loss_2 : 2.13 train loss_3 : 9.76 val loss_3 : 5.06
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 200 train loss_0 : 0.172 val loss_0 : 2.13 train loss_1 : 0.823 val loss_1 : 0.0142 train loss_2 : 0.172 val loss_2 : 2.13 train loss_3 : 10.1 val loss_3 : 5.13
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 280 train loss_0 : 0.168 val loss_0 : 2.06 train loss_1 : 0.832 val loss_1 : -0.0303 train loss_2 : 0.168 val loss_2 : 2.06 train loss_3 : 8.5 val loss_3 : 15.0
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 300 train loss_0 : 0.0695 val loss_0 : 2.02 train loss_1 : 0.941 val loss_1 : 0.0625 train loss_2 : 0.0695 val loss_2 : 2.02 train loss_3 : 3.33 val loss_3 : 8.35
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 320 train loss_0 : 0.0601 val loss_0 : 2.05 train loss_1 : 0.947 val loss_1 : 0.0273 train loss_2 : 0.0601 val loss_2 : 2.05 train loss_3 : 3.19 val loss_3 : 8.25
# ................................................................................................................................................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 340 train loss_0 : 0.0567 val loss_0 : 2.05 train loss_1 : 0.949 val loss_1 : 0.048 train loss_2 : 0.0567 val loss_2 : 2.05 train loss_3 : 3.14 val loss_3 : 7.95
# ................................(8, 5120)
# (8, 5120)
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 360 train loss_0 : 0.0536 val loss_0 : 2.02 train loss_1 : 0.953 val loss_1 : 0.0616 train loss_2 : 0.0536 val loss_2 : 2.02 train loss_3 : 3.08 val loss_3 : 8.02
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 380 train loss_0 : 0.0528 val loss_0 : 1.97 train loss_1 : 0.952 val loss_1 : 0.0624 train loss_2 : 0.0528 val loss_2 : 1.97 train loss_3 : 3.12 val loss_3 : 8.26
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 400 train loss_0 : 0.0517 val loss_0 : 1.96 train loss_1 : 0.955 val loss_1 : 0.0549 train loss_2 : 0.0517 val loss_2 : 1.96 train loss_3 : 3.07 val loss_3 : 8.54
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 420 train loss_0 : 0.0479 val loss_0 : 2.01 train loss_1 : 0.954 val loss_1 : 0.0504 train loss_2 : 0.0479 val loss_2 : 2.01 train loss_3 : 3.02 val loss_3 : 8.31
# ..................................................................................................................................................

# %% [markdown]
# #
