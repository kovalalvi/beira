# %% [markdown]
# # Install libraries

# %%
import sys, os, json
import mne, sklearn, wandb
import numpy as np
import pandas as pd

from scipy.interpolate import interp1d
from nilearn import datasets, image, masking, plotting
from nilearn.input_data import NiftiLabelsMasker


# animation part
from IPython.display import HTML
import matplotlib
import matplotlib.pyplot as plt
# from celluloid import Camera   # it is convinient method to animate
from matplotlib import animation, rc
from matplotlib.animation import FuncAnimation


## torch libraries 
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader, Subset

from pytorch_model_summary import summary
# Out:
# /opt/conda/envs/myenv_torch/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.insert(1, os.path.realpath(os.path.pardir))

from utils import get_datasets
from utils import preproc
from utils import torch_dataset
from utils import train_utils
from utils import inference
from utils.models_arch import autoencoder_new

# %% [markdown]
# # Set all hyperparameters
# - Cuda and GPU.
# - Parameters of dataset.
# - random seed( if necessary).

# %%
# import random

# torch.manual_seed(0)
# random.seed(0)  # python operation seed
# np.random.seed(0)

# torch.backends.cudnn.benchmark = False
# torch.backends.cudnn.deterministic = True

print(torch.cuda.is_available(), torch.cuda.device_count())
torch.cuda.set_device(0)
# Out:
# True 4

# %%
config = dict(  
                dataset_name = 'CWL', # CWL
                new_fps=100, 
                freqs = np.logspace(np.log10(2), np.log10(99), 16), 
    
                n_channels = 30, # 30 
                n_roi = 6,
                
                bold_delay = 6,
                to_many = True,
                random_subsample = True,
                sample_per_epoch = 512, 
                WINDOW_SIZE = 2048,
                    
                optimizer='adamW',
                lr=3e-4,
                weight_decay=3e-4, 
                batch_size=16, 
                
                preproc_type = 'dB_log',
                loss_function = 'mse_corr', 
                model_type = 'Best_AE_3_layers'
                )


hp_autoencoder = dict(n_electrodes=config['n_channels'],
                      n_freqs = len(config['freqs']),
                      n_channels_out = config['n_roi'],

                     channels = [128, 128, 128, 128], 
                     kernel_sizes=[5, 5, 3],
                     strides=[8, 8, 4,], 
                     dilation=[1, 1, 1], 
                     decoder_reduce=4
                     )


config = {**hp_autoencoder, **config}

params_train = {'batch_size': config['batch_size'],
                'shuffle': True,
                'num_workers': 0}

params_val = {'batch_size': config['batch_size'],
              'shuffle': False}

# %% [markdown]
# # Upload preprocessed dataset from np files.
# It should accelerate speed of experiments.

# %%
with open("../data/processed/labels_roi_6.json", 'r') as f:
    labels_roi = json.load(f)


if config['dataset_name']=='CWL':
    dataset_path = '../data/processed/CWL/trio1_100_hz_6_roi_2_99_freqs.npz'
    
elif config['dataset_name']=='NODDI':
    dataset_path = '../data/processed/NODDI/32_100_hz_6_roi_2_99_freqs.npz'
else:
    print('no such dataset')


# download data
data = np.load(dataset_path)

train_dataset_prep = (data['x_train'], data['y_train'])
test_dataset_prep = (data['x_test'], data['y_test'])


# apply time dealy corrected
train_dataset_prep = preproc.bold_time_delay_align(train_dataset_prep, 
                                                   config['new_fps'],
                                                   config['bold_delay'])
test_dataset_prep = preproc.bold_time_delay_align(test_dataset_prep, 
                                                  config['new_fps'],
                                                  config['bold_delay'])


print('Size of train dataset:', train_dataset_prep[0].shape, train_dataset_prep[1].shape)
print('Size of test dataset:', test_dataset_prep[0].shape, test_dataset_prep[1].shape)

# torch dataset creation 
torch_dataset_train = torch_dataset.CreateDataset_eeg_fmri(train_dataset_prep, 
                                                            random_sample=config['random_subsample'], 
                                                            sample_per_epoch=config['sample_per_epoch'], 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])

torch_dataset_test = torch_dataset.CreateDataset_eeg_fmri(test_dataset_prep, 
                                                            random_sample=False, 
                                                            sample_per_epoch=None, 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])
# because you do not have strid for val data. 
torch_dataset_test = Subset(torch_dataset_test, np.arange(len(torch_dataset_test))[::100])

# init dataloaders for training
train_loader = torch.utils.data.DataLoader(torch_dataset_train, **params_train)
val_loader = torch.utils.data.DataLoader(torch_dataset_test, **params_val)
# Out:
# Size of train dataset: (30, 16, 20590) (6, 20590)
# Size of test dataset: (30, 16, 5400) (6, 5400)

# %% [markdown]
# # Init Model, Loss, optimizers

# %%
model = autoencoder_new.AutoEncoder1D(**hp_autoencoder)

print(summary(model, torch.zeros(4, config['n_channels'], 
                                 len(config['freqs']),
                                 config['WINDOW_SIZE']), show_input=False))
# Out:
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#        ConvBlock-1      [4, 128, 2048]         184,576         184,576
#        ConvBlock-2       [4, 128, 256]          82,176          82,176
#        ConvBlock-3        [4, 128, 32]          82,176          82,176
#        ConvBlock-4         [4, 128, 8]          49,408          49,408
#      UpConvBlock-5         [4, 32, 32]          12,352          12,352
#      UpConvBlock-6        [4, 32, 256]           5,184           5,184
#      UpConvBlock-7       [4, 32, 2048]           5,184           5,184
#           Conv1d-8        [4, 6, 2048]             198             198
# =======================================================================
# Total params: 421,254
# Trainable params: 421,254
# Non-trainable params: 0
# -----------------------------------------------------------------------

# %% [markdown]
# # Model training

# %%
n_runs = 3

for i in range(n_runs):
    
    model = autoencoder_new.AutoEncoder1D(**hp_autoencoder)

    loss_func = train_utils.make_complex_loss_function(mse_weight = 0.1, 
                                                       corr_weight = 1,
                                                       manifold_weight = 0,
                                                       bound=1)
    train_step = train_utils.train_step

    optimizer = optim.AdamW(model.parameters(), 
                       lr=config['lr'], 
                       weight_decay=config['weight_decay'])
    
    
    parameters = {
        'EPOCHS': 5000,
        'model': model, 
        'train_loader': train_loader, 
        'val_loader': val_loader, 
        'loss_function': loss_func,
        'train_step': train_step,
        'optimizer': optimizer, 
        'device': 'cuda', 
        'raw_test_data': test_dataset_prep,
        'show_info': 20, 
        'num_losses': 5,
        'labels': labels_roi,
        'inference_function': inference.model_inference_function, 
        'to_many': config['to_many']
    }



    path_to_save_wandb = 'common/koval_alvi/Checkpoints/wandb_brain'
    
    
    with wandb.init(project="eeg_fmri", config=config, save_code=True):
        
        wandb.define_metric("val/corr_mean", summary="max")

        if i == 0: 
            exp_name = wandb.run.name
        
        wandb.run.name = exp_name +'_run_' + str(i)
        
        print(config)
        print(parameters['model'])
        print(summary(model, torch.zeros(4, config['n_channels'],
                                         len(config['freqs']), config['WINDOW_SIZE']), show_input=False))
        
        model = train_utils.wanb_train_regression(**parameters)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: koval_alvi (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.16 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/29p30ll8" target="_blank">sage-armadillo-387</a></strong> to <a href="https://wandb.ai/koval_alvi/eeg_fmri" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# {'n_electrodes': 30, 'n_freqs': 16, 'n_channels_out': 6, 'channels': [128, 128, 128, 128], 'kernel_sizes': [5, 5, 3], 'strides': [8, 8, 4], 'dilation': [1, 1, 1], 'decoder_reduce': 4, 'dataset_name': 'CWL', 'new_fps': 100, 'freqs': array([ 2.        ,  2.59420132,  3.36494024,  4.3646662 ,  5.6614114 ,
#         7.34342046,  9.52515552, 12.3550855 , 16.02578954, 20.78706217,
#        26.96291204, 34.97361097, 45.36429384, 58.84205542, 76.32406886,
#        99.        ]), 'n_channels': 30, 'n_roi': 6, 'bold_delay': 6, 'to_many': True, 'random_subsample': True, 'sample_per_epoch': 512, 'WINDOW_SIZE': 2048, 'optimizer': 'adamW', 'lr': 0.0003, 'weight_decay': 0.0003, 'batch_size': 16, 'preproc_type': 'dB_log', 'loss_function': 'mse_corr', 'model_type': 'Best_AE_3_layers'}
# AutoEncoder1D(
#   (spatial_reduce): ConvBlock(
#     (conv1d): Conv1d(480, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU()
#     (drop): Dropout(p=0.3, inplace=False)
#     (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downsample_blocks): ModuleList(
#     (0): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (upsample_blocks): ModuleList(
#     (0): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (1): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#     (2): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#   )
#   (conv1x1_one): Conv1d(32, 6, kernel_size=(1,), stride=(1,), padding=same)
# )
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#        ConvBlock-1      [4, 128, 2048]         184,576         184,576
#        ConvBlock-2       [4, 128, 256]          82,176          82,176
#        ConvBlock-3        [4, 128, 32]          82,176          82,176
#        ConvBlock-4         [4, 128, 8]          49,408          49,408
#      UpConvBlock-5         [4, 32, 32]          12,352          12,352
#      UpConvBlock-6        [4, 32, 256]           5,184           5,184
#      UpConvBlock-7       [4, 32, 2048]           5,184           5,184
#           Conv1d-8        [4, 6, 2048]             198             198
# =======================================================================
# Total params: 421,254
# Trainable params: 421,254
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Starting Training of our model
# Number of samples 512
# Size of batch: 16 Number batches 32
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 20 train loss_0 : -0.809 val loss_0 : -0.0643 train loss_1 : 0.84 val loss_1 : 0.228 train loss_2 : 0.308 val loss_2 : 1.64 train loss_3 : 3.7 val loss_3 : 7.97
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 40 train loss_0 : -0.856 val loss_0 : -0.0544 train loss_1 : 0.879 val loss_1 : 0.213 train loss_2 : 0.234 val loss_2 : 1.59 train loss_3 : 2.99 val loss_3 : 6.59
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 60 train loss_0 : -0.872 val loss_0 : -0.103 train loss_1 : 0.894 val loss_1 : 0.259 train loss_2 : 0.214 val loss_2 : 1.56 train loss_3 : 2.63 val loss_3 : 6.37
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 80 train loss_0 : -0.885 val loss_0 : -0.0881 train loss_1 : 0.904 val loss_1 : 0.258 train loss_2 : 0.192 val loss_2 : 1.69 train loss_3 : 2.42 val loss_3 : 5.78
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 100 train loss_0 : -0.889 val loss_0 : -0.0869 train loss_1 : 0.907 val loss_1 : 0.253 train loss_2 : 0.183 val loss_2 : 1.66 train loss_3 : 2.27 val loss_3 : 5.34
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 120 train loss_0 : -0.896 val loss_0 : -0.164 train loss_1 : 0.914 val loss_1 : 0.322 train loss_2 : 0.176 val loss_2 : 1.58 train loss_3 : 2.19 val loss_3 : 5.82
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 140 train loss_0 : -0.9 val loss_0 : -0.101 train loss_1 : 0.916 val loss_1 : 0.266 train loss_2 : 0.168 val loss_2 : 1.65 train loss_3 : 2.14 val loss_3 : 5.88
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 160 train loss_0 : -0.901 val loss_0 : -0.177 train loss_1 : 0.917 val loss_1 : 0.316 train loss_2 : 0.163 val loss_2 : 1.39 train loss_3 : 2.07 val loss_3 : 5.66
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 180 train loss_0 : -0.904 val loss_0 : -0.22 train loss_1 : 0.92 val loss_1 : 0.362 train loss_2 : 0.16 val loss_2 : 1.42 train loss_3 : 1.99 val loss_3 : 5.33
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 200 train loss_0 : -0.908 val loss_0 : -0.165 train loss_1 : 0.923 val loss_1 : 0.311 train loss_2 : 0.154 val loss_2 : 1.47 train loss_3 : 1.93 val loss_3 : 5.64
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 220 train loss_0 : -0.908 val loss_0 : -0.228 train loss_1 : 0.924 val loss_1 : 0.37 train loss_2 : 0.153 val loss_2 : 1.41 train loss_3 : 1.93 val loss_3 : 5.32
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 240 train loss_0 : -0.909 val loss_0 : -0.14 train loss_1 : 0.924 val loss_1 : 0.299 train loss_2 : 0.151 val loss_2 : 1.59 train loss_3 : 1.88 val loss_3 : 5.36
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 260 train loss_0 : -0.911 val loss_0 : -0.223 train loss_1 : 0.926 val loss_1 : 0.365 train loss_2 : 0.151 val loss_2 : 1.42 train loss_3 : 1.84 val loss_3 : 5.29
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 280 train loss_0 : -0.912 val loss_0 : -0.226 train loss_1 : 0.927 val loss_1 : 0.367 train loss_2 : 0.149 val loss_2 : 1.4 train loss_3 : 1.86 val loss_3 : 5.46
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 300 train loss_0 : -0.914 val loss_0 : -0.17 train loss_1 : 0.928 val loss_1 : 0.32 train loss_2 : 0.145 val loss_2 : 1.5 train loss_3 : 1.86 val loss_3 : 5.13
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 320 train loss_0 : -0.914 val loss_0 : -0.264 train loss_1 : 0.928 val loss_1 : 0.396 train loss_2 : 0.144 val loss_2 : 1.32 train loss_3 : 1.82 val loss_3 : 5.23
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 340 train loss_0 : -0.915 val loss_0 : -0.22 train loss_1 : 0.929 val loss_1 : 0.361 train loss_2 : 0.144 val loss_2 : 1.41 train loss_3 : 1.81 val loss_3 : 5.84
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 360 train loss_0 : -0.916 val loss_0 : -0.193 train loss_1 : 0.93 val loss_1 : 0.336 train loss_2 : 0.141 val loss_2 : 1.43 train loss_3 : 1.77 val loss_3 : 5.41
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 380 train loss_0 : -0.916 val loss_0 : -0.199 train loss_1 : 0.93 val loss_1 : 0.346 train loss_2 : 0.144 val loss_2 : 1.47 train loss_3 : 1.79 val loss_3 : 5.79
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 400 train loss_0 : -0.916 val loss_0 : -0.333 train loss_1 : 0.93 val loss_1 : 0.456 train loss_2 : 0.141 val loss_2 : 1.23 train loss_3 : 1.8 val loss_3 : 5.1
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 420 train loss_0 : -0.916 val loss_0 : -0.273 train loss_1 : 0.93 val loss_1 : 0.412 train loss_2 : 0.138 val loss_2 : 1.39 train loss_3 : 1.79 val loss_3 : 5.03
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 440 train loss_0 : -0.916 val loss_0 : -0.276 train loss_1 : 0.93 val loss_1 : 0.401 train loss_2 : 0.14 val loss_2 : 1.25 train loss_3 : 1.76 val loss_3 : 5.27
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 460 train loss_0 : -0.917 val loss_0 : -0.262 train loss_1 : 0.931 val loss_1 : 0.4 train loss_2 : 0.138 val loss_2 : 1.39 train loss_3 : 1.72 val loss_3 : 5.27
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 480 train loss_0 : -0.917 val loss_0 : -0.262 train loss_1 : 0.931 val loss_1 : 0.401 train loss_2 : 0.138 val loss_2 : 1.39 train loss_3 : 1.72 val loss_3 : 4.99
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 500 train loss_0 : -0.916 val loss_0 : -0.306 train loss_1 : 0.93 val loss_1 : 0.438 train loss_2 : 0.138 val loss_2 : 1.32 train loss_3 : 1.71 val loss_3 : 4.72
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 520 train loss_0 : -0.917 val loss_0 : -0.242 train loss_1 : 0.931 val loss_1 : 0.387 train loss_2 : 0.136 val loss_2 : 1.44 train loss_3 : 1.73 val loss_3 : 5.61
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 540 train loss_0 : -0.918 val loss_0 : -0.201 train loss_1 : 0.932 val loss_1 : 0.35 train loss_2 : 0.137 val loss_2 : 1.5 train loss_3 : 1.73 val loss_3 : 5.01
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 560 train loss_0 : -0.919 val loss_0 : -0.257 train loss_1 : 0.933 val loss_1 : 0.412 train loss_2 : 0.133 val loss_2 : 1.56 train loss_3 : 1.7 val loss_3 : 5.33
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 580 train loss_0 : -0.921 val loss_0 : -0.232 train loss_1 : 0.934 val loss_1 : 0.377 train loss_2 : 0.132 val loss_2 : 1.45 train loss_3 : 1.7 val loss_3 : 5.17
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 600 train loss_0 : -0.919 val loss_0 : -0.268 train loss_1 : 0.932 val loss_1 : 0.412 train loss_2 : 0.136 val loss_2 : 1.44 train loss_3 : 1.72 val loss_3 : 4.89
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 620 train loss_0 : -0.919 val loss_0 : -0.261 train loss_1 : 0.932 val loss_1 : 0.402 train loss_2 : 0.135 val loss_2 : 1.41 train loss_3 : 1.72 val loss_3 : 4.98
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 640 train loss_0 : -0.919 val loss_0 : -0.186 train loss_1 : 0.933 val loss_1 : 0.35 train loss_2 : 0.137 val loss_2 : 1.64 train loss_3 : 1.71 val loss_3 : 5.35
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 660 train loss_0 : -0.92 val loss_0 : -0.297 train loss_1 : 0.933 val loss_1 : 0.435 train loss_2 : 0.134 val loss_2 : 1.38 train loss_3 : 1.68 val loss_3 : 5.38
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 680 train loss_0 : -0.92 val loss_0 : -0.344 train loss_1 : 0.934 val loss_1 : 0.471 train loss_2 : 0.135 val loss_2 : 1.26 train loss_3 : 1.69 val loss_3 : 4.87
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 700 train loss_0 : -0.919 val loss_0 : -0.216 train loss_1 : 0.933 val loss_1 : 0.364 train loss_2 : 0.134 val loss_2 : 1.48 train loss_3 : 1.69 val loss_3 : 5.07
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 720 train loss_0 : -0.921 val loss_0 : -0.318 train loss_1 : 0.934 val loss_1 : 0.448 train loss_2 : 0.132 val loss_2 : 1.3 train loss_3 : 1.67 val loss_3 : 4.85
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 740 train loss_0 : -0.921 val loss_0 : -0.306 train loss_1 : 0.935 val loss_1 : 0.452 train loss_2 : 0.134 val loss_2 : 1.46 train loss_3 : 1.66 val loss_3 : 5.15
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 760 train loss_0 : -0.921 val loss_0 : -0.257 train loss_1 : 0.934 val loss_1 : 0.403 train loss_2 : 0.132 val loss_2 : 1.46 train loss_3 : 1.66 val loss_3 : 4.98
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 780 train loss_0 : -0.922 val loss_0 : -0.214 train loss_1 : 0.935 val loss_1 : 0.371 train loss_2 : 0.132 val loss_2 : 1.56 train loss_3 : 1.65 val loss_3 : 5.14
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 800 train loss_0 : -0.921 val loss_0 : -0.302 train loss_1 : 0.934 val loss_1 : 0.439 train loss_2 : 0.132 val loss_2 : 1.37 train loss_3 : 1.67 val loss_3 : 5.25
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 820 train loss_0 : -0.921 val loss_0 : -0.27 train loss_1 : 0.934 val loss_1 : 0.413 train loss_2 : 0.131 val loss_2 : 1.42 train loss_3 : 1.67 val loss_3 : 5.17
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 840 train loss_0 : -0.922 val loss_0 : -0.325 train loss_1 : 0.935 val loss_1 : 0.457 train loss_2 : 0.133 val loss_2 : 1.32 train loss_3 : 1.67 val loss_3 : 5.14
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 860 train loss_0 : -0.922 val loss_0 : -0.299 train loss_1 : 0.935 val loss_1 : 0.436 train loss_2 : 0.13 val loss_2 : 1.37 train loss_3 : 1.68 val loss_3 : 4.94
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 880 train loss_0 : -0.923 val loss_0 : -0.276 train loss_1 : 0.935 val loss_1 : 0.416 train loss_2 : 0.129 val loss_2 : 1.41 train loss_3 : 1.68 val loss_3 : 4.98
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 900 train loss_0 : -0.922 val loss_0 : -0.276 train loss_1 : 0.935 val loss_1 : 0.427 train loss_2 : 0.131 val loss_2 : 1.51 train loss_3 : 1.63 val loss_3 : 5.24
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 920 train loss_0 : -0.923 val loss_0 : -0.257 train loss_1 : 0.936 val loss_1 : 0.411 train loss_2 : 0.131 val loss_2 : 1.54 train loss_3 : 1.65 val loss_3 : 5.32
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 940 train loss_0 : -0.922 val loss_0 : -0.276 train loss_1 : 0.935 val loss_1 : 0.42 train loss_2 : 0.129 val loss_2 : 1.44 train loss_3 : 1.68 val loss_3 : 5.25
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 960 train loss_0 : -0.922 val loss_0 : -0.263 train loss_1 : 0.935 val loss_1 : 0.414 train loss_2 : 0.129 val loss_2 : 1.5 train loss_3 : 1.65 val loss_3 : 4.78
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 980 train loss_0 : -0.922 val loss_0 : -0.206 train loss_1 : 0.935 val loss_1 : 0.361 train loss_2 : 0.129 val loss_2 : 1.54 train loss_3 : 1.66 val loss_3 : 5.59
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 1000 train loss_0 : -0.922 val loss_0 : -0.27 train loss_1 : 0.935 val loss_1 : 0.423 train loss_2 : 0.128 val loss_2 : 1.53 train loss_3 : 1.65 val loss_3 : 5.25
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 1020 train loss_0 : -0.922 val loss_0 : -0.326 train loss_1 : 0.935 val loss_1 : 0.457 train loss_2 : 0.131 val loss_2 : 1.32 train loss_3 : 1.64 val loss_3 : 5.06
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 1040 train loss_0 : -0.922 val loss_0 : -0.273 train loss_1 : 0.935 val loss_1 : 0.421 train loss_2 : 0.129 val loss_2 : 1.48 train loss_3 : 1.64 val loss_3 : 5.45
# ...
# Epoch 4180 train loss_0 : -0.926 val loss_0 : -0.233 train loss_1 : 0.938 val loss_1 : 0.38 train loss_2 : 0.12 val loss_2 : 1.47 train loss_3 : 1.6 val loss_3 : 5.49
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4200 train loss_0 : -0.927 val loss_0 : -0.309 train loss_1 : 0.939 val loss_1 : 0.442 train loss_2 : 0.123 val loss_2 : 1.34 train loss_3 : 1.6 val loss_3 : 4.89
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4220 train loss_0 : -0.926 val loss_0 : -0.287 train loss_1 : 0.938 val loss_1 : 0.419 train loss_2 : 0.119 val loss_2 : 1.32 train loss_3 : 1.59 val loss_3 : 4.69
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4240 train loss_0 : -0.926 val loss_0 : -0.272 train loss_1 : 0.938 val loss_1 : 0.409 train loss_2 : 0.121 val loss_2 : 1.37 train loss_3 : 1.59 val loss_3 : 5.06
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4260 train loss_0 : -0.926 val loss_0 : -0.259 train loss_1 : 0.939 val loss_1 : 0.399 train loss_2 : 0.123 val loss_2 : 1.4 train loss_3 : 1.55 val loss_3 : 5.11
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4280 train loss_0 : -0.926 val loss_0 : -0.262 train loss_1 : 0.938 val loss_1 : 0.408 train loss_2 : 0.124 val loss_2 : 1.46 train loss_3 : 1.59 val loss_3 : 5.17
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4300 train loss_0 : -0.926 val loss_0 : -0.349 train loss_1 : 0.939 val loss_1 : 0.468 train loss_2 : 0.122 val loss_2 : 1.2 train loss_3 : 1.61 val loss_3 : 5.14
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4320 train loss_0 : -0.927 val loss_0 : -0.334 train loss_1 : 0.939 val loss_1 : 0.469 train loss_2 : 0.124 val loss_2 : 1.35 train loss_3 : 1.57 val loss_3 : 4.86
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4340 train loss_0 : -0.926 val loss_0 : -0.227 train loss_1 : 0.938 val loss_1 : 0.371 train loss_2 : 0.123 val loss_2 : 1.45 train loss_3 : 1.58 val loss_3 : 5.07
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4360 train loss_0 : -0.927 val loss_0 : -0.242 train loss_1 : 0.94 val loss_1 : 0.385 train loss_2 : 0.122 val loss_2 : 1.43 train loss_3 : 1.6 val loss_3 : 5.02
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4380 train loss_0 : -0.927 val loss_0 : -0.244 train loss_1 : 0.939 val loss_1 : 0.393 train loss_2 : 0.122 val loss_2 : 1.5 train loss_3 : 1.61 val loss_3 : 5.05
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4400 train loss_0 : -0.927 val loss_0 : -0.234 train loss_1 : 0.939 val loss_1 : 0.381 train loss_2 : 0.122 val loss_2 : 1.47 train loss_3 : 1.6 val loss_3 : 5.17
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4420 train loss_0 : -0.927 val loss_0 : -0.305 train loss_1 : 0.939 val loss_1 : 0.441 train loss_2 : 0.124 val loss_2 : 1.36 train loss_3 : 1.6 val loss_3 : 5.03
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4440 train loss_0 : -0.927 val loss_0 : -0.315 train loss_1 : 0.939 val loss_1 : 0.451 train loss_2 : 0.122 val loss_2 : 1.36 train loss_3 : 1.59 val loss_3 : 5.07
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4460 train loss_0 : -0.927 val loss_0 : -0.267 train loss_1 : 0.939 val loss_1 : 0.404 train loss_2 : 0.121 val loss_2 : 1.36 train loss_3 : 1.57 val loss_3 : 5.03
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4480 train loss_0 : -0.927 val loss_0 : -0.297 train loss_1 : 0.939 val loss_1 : 0.427 train loss_2 : 0.123 val loss_2 : 1.3 train loss_3 : 1.59 val loss_3 : 5.07
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4500 train loss_0 : -0.927 val loss_0 : -0.271 train loss_1 : 0.939 val loss_1 : 0.413 train loss_2 : 0.121 val loss_2 : 1.42 train loss_3 : 1.58 val loss_3 : 5.26
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4520 train loss_0 : -0.927 val loss_0 : -0.263 train loss_1 : 0.939 val loss_1 : 0.401 train loss_2 : 0.122 val loss_2 : 1.38 train loss_3 : 1.59 val loss_3 : 5.33
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4540 train loss_0 : -0.926 val loss_0 : -0.223 train loss_1 : 0.938 val loss_1 : 0.379 train loss_2 : 0.12 val loss_2 : 1.56 train loss_3 : 1.57 val loss_3 : 4.99
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 4560 train loss_0 : -0.926 val loss_0 : -0.208 train loss_1 : 0.939 val loss_1 : 0.361 train loss_2 : 0.121 val loss_2 : 1.53 train loss_3 : 1.58 val loss_3 : 5.28
# ...............................................................................................................................................................................................................................................................................

# %% [markdown]
# #
