# %% [markdown]
# # Install libraries

# %%
import sys, os, json
import mne, sklearn, wandb
import numpy as np
import pandas as pd

from scipy.interpolate import interp1d
from nilearn import datasets, image, masking, plotting
from nilearn.input_data import NiftiLabelsMasker


# animation part
from IPython.display import HTML
import matplotlib
import matplotlib.pyplot as plt
# from celluloid import Camera   # it is convinient method to animate
from matplotlib import animation, rc
from matplotlib.animation import FuncAnimation


## torch libraries 
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader, Subset

from pytorch_model_summary import summary
# Out:
# /opt/conda/envs/myenv_torch/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.insert(1, os.path.realpath(os.path.pardir))

from utils import get_datasets
from utils import preproc
from utils import torch_dataset
from utils import train_utils
from utils import inference
from utils.models_arch import autoencoder_new

# %% [markdown]
# # Set all hyperparameters
# - Cuda and GPU.
# - Parameters of dataset.
# - random seed( if necessary).

# %%
# import random

# torch.manual_seed(0)
# random.seed(0)  # python operation seed
# np.random.seed(0)

# torch.backends.cudnn.benchmark = False
# torch.backends.cudnn.deterministic = True

print(torch.cuda.is_available(), torch.cuda.device_count())
torch.cuda.set_device(0)
# Out:
# True 4

# %%
config = dict(  
                dataset_name = 'NODDI', # CWL
                new_fps=100, 
                freqs = np.logspace(np.log10(2), np.log10(99), 16), 
    
                n_channels = 63, # 30 
                n_roi = 6,
                
                bold_delay = 5,
                to_many = True,
                random_subsample = True,
                sample_per_epoch = 2048, 
                WINDOW_SIZE = 2048,
                    
                optimizer='adam',
                lr=3e-4,
                weight_decay=0, 
                batch_size=16, 
                
                preproc_type = 'dB_log',
                loss_function = 'mse', 
                model_type = '1D_CNN_AE_wav2vec2'
                )


hp_autoencoder = dict(n_electrodes=config['n_channels'],
                      n_freqs = len(config['freqs']),
                      n_channels_out = config['n_roi'],

                     channels = [256, 128, 128, 128], 
                     kernel_sizes=[3, 3, 3],
                     strides=[8, 4, 4], 
                     dilation=[1, 1, 1], 
                     decoder_reduce=4
                     )


config = {**hp_autoencoder, **config}

params_train = {'batch_size': config['batch_size'],
                'shuffle': True,
                'num_workers': 0}

params_val = {'batch_size': config['batch_size'],
              'shuffle': False}

# %% [markdown]
# # Upload preprocessed dataset from np files.
# It should accelerate speed of experiments.

# %%
with open("../data/processed/labels_roi_6.json", 'r') as f:
    labels_roi = json.load(f)


if config['dataset_name']=='CWL':
    dataset_path = '../data/processed/CWL/trio1_100_hz_6_roi_2_99_freqs.npz'
    
elif config['dataset_name']=='NODDI':
     # dataset_path = '../data/interim/NODDI/32_250_filtered_data.npz'
    dataset_path = '../data/processed/NODDI/32_100_hz_6_roi_2_99_freqs.npz'
else:
    print('no such dataset')


# download data
data = np.load(dataset_path)

train_dataset_prep = (data['x_train'], data['y_train'])
test_dataset_prep = (data['x_test'], data['y_test'])


# apply time dealy corrected
train_dataset_prep = preproc.bold_time_delay_align(train_dataset_prep, 
                                                   config['new_fps'],
                                                   config['bold_delay'])
test_dataset_prep = preproc.bold_time_delay_align(test_dataset_prep, 
                                                  config['new_fps'],
                                                  config['bold_delay'])


print('Size of train dataset:', train_dataset_prep[0].shape, train_dataset_prep[1].shape)
print('Size of test dataset:', test_dataset_prep[0].shape, test_dataset_prep[1].shape)

# torch dataset creation 
torch_dataset_train = torch_dataset.CreateDataset_eeg_fmri(train_dataset_prep, 
                                                            random_sample=config['random_subsample'], 
                                                            sample_per_epoch=config['sample_per_epoch'], 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])

torch_dataset_test = torch_dataset.CreateDataset_eeg_fmri(test_dataset_prep, 
                                                            random_sample=False, 
                                                            sample_per_epoch=None, 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])
# because you do not have strid for val data. 
torch_dataset_test = Subset(torch_dataset_test, np.arange(len(torch_dataset_test))[::100])

# init dataloaders for training
train_loader = torch.utils.data.DataLoader(torch_dataset_train, **params_train)
val_loader = torch.utils.data.DataLoader(torch_dataset_test, **params_val)
# Out:
# Size of train dataset: (63, 16, 57584) (6, 57584)
# Size of test dataset: (63, 16, 5500) (6, 5500)

# %% [markdown]
# # Init Model, Loss, optimizers

# %%
model = autoencoder_new.AutoEncoder1D(**hp_autoencoder)

print(summary(model, torch.zeros(4, config['n_channels'], 
                                 len(config['freqs']),
                                 config['WINDOW_SIZE']), show_input=False))
# Out:
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#        ConvBlock-1      [4, 256, 2048]         774,656         774,656
#        ConvBlock-2       [4, 128, 256]          98,560          98,560
#        ConvBlock-3        [4, 128, 64]          49,408          49,408
#        ConvBlock-4        [4, 128, 16]          49,408          49,408
#      UpConvBlock-5         [4, 32, 64]          12,352          12,352
#      UpConvBlock-6        [4, 32, 256]           3,136           3,136
#      UpConvBlock-7       [4, 64, 2048]           6,272           6,272
#           Conv1d-8        [4, 6, 2048]             390             390
# =======================================================================
# Total params: 994,182
# Trainable params: 994,182
# Non-trainable params: 0
# -----------------------------------------------------------------------

# %% [markdown]
# # Model training

# %%
n_runs = 3

for i in range(n_runs):
    
    model = autoencoder_new.AutoEncoder1D(**hp_autoencoder)

    loss_func = train_utils.make_complex_loss_function(mse_weight = 1, 
                                                       corr_weight = 0,
                                                       manifold_weight = 0,
                                                       bound=1)
    train_step = train_utils.train_step

    optimizer = optim.Adam(model.parameters(), 
                       lr=config['lr'], 
                       weight_decay=config['weight_decay'])
    
    
    parameters = {
        'EPOCHS': 250,
        'model': model, 
        'train_loader': train_loader, 
        'val_loader': val_loader, 
        'loss_function': loss_func,
        'train_step': train_step,
        'optimizer': optimizer, 
        'device': 'cuda', 
        'raw_test_data': test_dataset_prep,
        'show_info': 10, 
        'num_losses': 5,
        'labels': labels_roi,
        'inference_function': inference.model_inference_function, 
        'to_many': config['to_many']
    }



    path_to_save_wandb = 'common/koval_alvi/Checkpoints/wandb_brain'
    
    
    with wandb.init(project="eeg_fmri", config=config, save_code=True):
        
        wandb.define_metric("val/corr_mean", summary="max")

        if i == 0: 
            exp_name = wandb.run.name
        
        wandb.run.name = exp_name +'_run_' + str(i)
        
        print(config)
        print(parameters['model'])
        print(summary(model, torch.zeros(4, config['n_channels'],
                                         len(config['freqs']), config['WINDOW_SIZE']), show_input=False))
        
        model = train_utils.wanb_train_regression(**parameters)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: koval_alvi (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/228tykl2" target="_blank">spiced-bun-198</a></strong> to <a href="https://wandb.ai/koval_alvi/eeg_fmri" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# {'n_electrodes': 63, 'n_freqs': 16, 'n_channels_out': 6, 'channels': [256, 128, 128, 128], 'kernel_sizes': [3, 3, 3], 'strides': [8, 4, 4], 'dilation': [1, 1, 1], 'decoder_reduce': 4, 'dataset_name': 'NODDI', 'new_fps': 100, 'freqs': array([ 2.        ,  2.59420132,  3.36494024,  4.3646662 ,  5.6614114 ,
#         7.34342046,  9.52515552, 12.3550855 , 16.02578954, 20.78706217,
#        26.96291204, 34.97361097, 45.36429384, 58.84205542, 76.32406886,
#        99.        ]), 'n_channels': 63, 'n_roi': 6, 'bold_delay': 5, 'to_many': True, 'random_subsample': True, 'sample_per_epoch': 2048, 'WINDOW_SIZE': 2048, 'optimizer': 'adam', 'lr': 0.0003, 'weight_decay': 0, 'batch_size': 16, 'preproc_type': 'dB_log', 'loss_function': 'mse', 'model_type': '1D_CNN_AE_wav2vec2'}
# AutoEncoder1D(
#   (spatial_reduce): ConvBlock(
#     (conv1d): Conv1d(1008, 256, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU()
#     (drop): Dropout(p=0.3, inplace=False)
#     (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downsample_blocks): ModuleList(
#     (0): ConvBlock(
#       (conv1d): Conv1d(256, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (upsample_blocks): ModuleList(
#     (0): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (1): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (2): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#   )
#   (conv1x1_one): Conv1d(64, 6, kernel_size=(1,), stride=(1,), padding=same)
# )
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#        ConvBlock-1      [4, 256, 2048]         774,656         774,656
#        ConvBlock-2       [4, 128, 256]          98,560          98,560
#        ConvBlock-3        [4, 128, 64]          49,408          49,408
#        ConvBlock-4        [4, 128, 16]          49,408          49,408
#      UpConvBlock-5         [4, 32, 64]          12,352          12,352
#      UpConvBlock-6        [4, 32, 256]           3,136           3,136
#      UpConvBlock-7       [4, 64, 2048]           6,272           6,272
#           Conv1d-8        [4, 6, 2048]             390             390
# =======================================================================
# Total params: 994,182
# Trainable params: 994,182
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Starting Training of our model
# Number of samples 2048
# Size of batch: 16 Number batches 128
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 10 train loss_0 : 0.991 val loss_0 : 1.16 train loss_1 : 0.000553 val loss_1 : -0.015 train loss_2 : 0.991 val loss_2 : 1.16 train loss_3 : 10.0 val loss_3 : 10.0
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 20 train loss_0 : 0.689 val loss_0 : 1.17 train loss_1 : 0.465 val loss_1 : 0.122 train loss_2 : 0.689 val loss_2 : 1.17 train loss_3 : 9.96 val loss_3 : 10.0
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 30 train loss_0 : 0.283 val loss_0 : 1.38 train loss_1 : 0.812 val loss_1 : 0.00456 train loss_2 : 0.283 val loss_2 : 1.38 train loss_3 : 4.21 val loss_3 : 7.82
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 40 train loss_0 : 0.191 val loss_0 : 1.44 train loss_1 : 0.874 val loss_1 : -0.034 train loss_2 : 0.191 val loss_2 : 1.44 train loss_3 : 2.15 val loss_3 : 6.42
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 50 train loss_0 : 0.155 val loss_0 : 1.49 train loss_1 : 0.898 val loss_1 : -0.0601 train loss_2 : 0.155 val loss_2 : 1.49 train loss_3 : 1.57 val loss_3 : 5.61
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 60 train loss_0 : 0.138 val loss_0 : 1.54 train loss_1 : 0.908 val loss_1 : -0.0701 train loss_2 : 0.138 val loss_2 : 1.54 train loss_3 : 1.44 val loss_3 : 5.25
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 70 train loss_0 : 0.131 val loss_0 : 1.49 train loss_1 : 0.913 val loss_1 : -0.0409 train loss_2 : 0.131 val loss_2 : 1.49 train loss_3 : 1.39 val loss_3 : 5.25
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 80 train loss_0 : 0.125 val loss_0 : 1.47 train loss_1 : 0.916 val loss_1 : -0.054 train loss_2 : 0.125 val loss_2 : 1.47 train loss_3 : 1.36 val loss_3 : 5.41
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 90 train loss_0 : 0.119 val loss_0 : 1.53 train loss_1 : 0.918 val loss_1 : -0.0952 train loss_2 : 0.119 val loss_2 : 1.53 train loss_3 : 1.33 val loss_3 : 5.26
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 100 train loss_0 : 0.117 val loss_0 : 1.48 train loss_1 : 0.922 val loss_1 : -0.0915 train loss_2 : 0.117 val loss_2 : 1.48 train loss_3 : 1.3 val loss_3 : 5.03
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 110 train loss_0 : 0.115 val loss_0 : 1.47 train loss_1 : 0.924 val loss_1 : -0.0708 train loss_2 : 0.115 val loss_2 : 1.47 train loss_3 : 1.29 val loss_3 : 5.19
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 120 train loss_0 : 0.112 val loss_0 : 1.48 train loss_1 : 0.925 val loss_1 : -0.0858 train loss_2 : 0.112 val loss_2 : 1.48 train loss_3 : 1.29 val loss_3 : 5.49
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 130 train loss_0 : 0.111 val loss_0 : 1.38 train loss_1 : 0.926 val loss_1 : -0.0113 train loss_2 : 0.111 val loss_2 : 1.38 train loss_3 : 1.26 val loss_3 : 5.36
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 140 train loss_0 : 0.109 val loss_0 : 1.48 train loss_1 : 0.927 val loss_1 : -0.0184 train loss_2 : 0.109 val loss_2 : 1.48 train loss_3 : 1.26 val loss_3 : 4.97
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 150 train loss_0 : 0.108 val loss_0 : 1.38 train loss_1 : 0.927 val loss_1 : -0.00453 train loss_2 : 0.108 val loss_2 : 1.38 train loss_3 : 1.26 val loss_3 : 5.35
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 160 train loss_0 : 0.107 val loss_0 : 1.42 train loss_1 : 0.928 val loss_1 : -0.037 train loss_2 : 0.107 val loss_2 : 1.42 train loss_3 : 1.25 val loss_3 : 5.51
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 170 train loss_0 : 0.106 val loss_0 : 1.47 train loss_1 : 0.928 val loss_1 : -0.0312 train loss_2 : 0.106 val loss_2 : 1.47 train loss_3 : 1.23 val loss_3 : 5.4
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 180 train loss_0 : 0.105 val loss_0 : 1.39 train loss_1 : 0.93 val loss_1 : -0.00743 train loss_2 : 0.105 val loss_2 : 1.39 train loss_3 : 1.23 val loss_3 : 5.58
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 190 train loss_0 : 0.104 val loss_0 : 1.35 train loss_1 : 0.93 val loss_1 : 0.00828 train loss_2 : 0.104 val loss_2 : 1.35 train loss_3 : 1.22 val loss_3 : 5.47
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 200 train loss_0 : 0.103 val loss_0 : 1.41 train loss_1 : 0.93 val loss_1 : -0.00851 train loss_2 : 0.103 val loss_2 : 1.41 train loss_3 : 1.21 val loss_3 : 5.48
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 210 train loss_0 : 0.103 val loss_0 : 1.35 train loss_1 : 0.931 val loss_1 : -0.0116 train loss_2 : 0.103 val loss_2 : 1.35 train loss_3 : 1.21 val loss_3 : 5.72
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 220 train loss_0 : 0.102 val loss_0 : 1.38 train loss_1 : 0.932 val loss_1 : -0.0163 train loss_2 : 0.102 val loss_2 : 1.38 train loss_3 : 1.2 val loss_3 : 5.8
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 230 train loss_0 : 0.102 val loss_0 : 1.5 train loss_1 : 0.932 val loss_1 : -0.0406 train loss_2 : 0.102 val loss_2 : 1.5 train loss_3 : 1.2 val loss_3 : 5.38
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 240 train loss_0 : 0.1 val loss_0 : 1.35 train loss_1 : 0.932 val loss_1 : -0.00118 train loss_2 : 0.1 val loss_2 : 1.35 train loss_3 : 1.21 val loss_3 : 5.66
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 250 train loss_0 : 0.0993 val loss_0 : 1.38 train loss_1 : 0.933 val loss_1 : 0.00502 train loss_2 : 0.0993 val loss_2 : 1.38 train loss_3 : 1.19 val loss_3 : 5.62
# <br/>Waiting for W&B process to finish, PID 14295... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 1.81MB of 1.81MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>train/loss_0</td><td>███▆▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_1</td><td>▁▁▁▄▆▇██████████████████████████████████</td></tr><tr><td>train/loss_2</td><td>███▆▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_3</td><td>████▆▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/corr_mean</td><td>▃▁▂▇█</td></tr><tr><td>val/loss_0</td><td>▁▁▁▁▅▆▆▆▆▆▇▇▇███▇▇▆▆▆▆▇▆▅▆▆▇▅▄▆▆▆▅▆▆▇▆▅▇</td></tr><tr><td>val/loss_1</td><td>▃▃▄█▃▄▃▄▂▃▃▃▂▂▁▂▂▂▃▂▄▃▃▄▄▃▃▃▄▄▂▂▄▄▄▄▃▃▄▃</td></tr><tr><td>val/loss_2</td><td>▁▁▁▁▅▆▆▆▆▆▇▇▇███▇▇▆▆▆▆▇▆▅▆▆▇▅▄▆▆▆▅▆▆▇▆▅▇</td></tr><tr><td>val/loss_3</td><td>█████▄▃▂▂▂▂▁▁▁▁▁▁▁▂▂▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/loss_0</td><td>0.09934</td></tr><tr><td>train/loss_1</td><td>0.93298</td></tr><tr><td>train/loss_2</td><td>0.09934</td></tr><tr><td>train/loss_3</td><td>1.19369</td></tr><tr><td>val/loss_0</td><td>1.37964</td></tr><tr><td>val/loss_1</td><td>0.00502</td></tr><tr><td>val/loss_2</td><td>1.37964</td></tr><tr><td>val/loss_3</td><td>5.61769</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 10 media file(s), 0 artifact file(s) and 2 other file(s)
# <br/>Synced <strong style="color:#cdcd00">spiced-bun-198</strong>: <a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/228tykl2" target="_blank">https://wandb.ai/koval_alvi/eeg_fmri/runs/228tykl2</a><br/>
# Find logs at: <code>./wandb/run-20220314_110151-228tykl2/logs</code><br/>
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/246j6r6y" target="_blank">pecan-square-207</a></strong> to <a href="https://wandb.ai/koval_alvi/eeg_fmri" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# {'n_electrodes': 63, 'n_freqs': 16, 'n_channels_out': 6, 'channels': [256, 128, 128, 128], 'kernel_sizes': [3, 3, 3], 'strides': [8, 4, 4], 'dilation': [1, 1, 1], 'decoder_reduce': 4, 'dataset_name': 'NODDI', 'new_fps': 100, 'freqs': array([ 2.        ,  2.59420132,  3.36494024,  4.3646662 ,  5.6614114 ,
#         7.34342046,  9.52515552, 12.3550855 , 16.02578954, 20.78706217,
#        26.96291204, 34.97361097, 45.36429384, 58.84205542, 76.32406886,
#        99.        ]), 'n_channels': 63, 'n_roi': 6, 'bold_delay': 5, 'to_many': True, 'random_subsample': True, 'sample_per_epoch': 2048, 'WINDOW_SIZE': 2048, 'optimizer': 'adam', 'lr': 0.0003, 'weight_decay': 0, 'batch_size': 16, 'preproc_type': 'dB_log', 'loss_function': 'mse', 'model_type': '1D_CNN_AE_wav2vec2'}
# AutoEncoder1D(
#   (spatial_reduce): ConvBlock(
#     (conv1d): Conv1d(1008, 256, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU()
#     (drop): Dropout(p=0.3, inplace=False)
#     (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downsample_blocks): ModuleList(
#     (0): ConvBlock(
#       (conv1d): Conv1d(256, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (upsample_blocks): ModuleList(
#     (0): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (1): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (2): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#   )
#   (conv1x1_one): Conv1d(64, 6, kernel_size=(1,), stride=(1,), padding=same)
# )
# -----------------------------------------------------------------------
# ...
# Epoch 210 train loss_0 : 0.102 val loss_0 : 1.51 train loss_1 : 0.931 val loss_1 : -0.103 train loss_2 : 0.102 val loss_2 : 1.51 train loss_3 : 1.22 val loss_3 : 5.1
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 220 train loss_0 : 0.101 val loss_0 : 1.45 train loss_1 : 0.931 val loss_1 : -0.0591 train loss_2 : 0.101 val loss_2 : 1.45 train loss_3 : 1.2 val loss_3 : 5.38
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 230 train loss_0 : 0.1 val loss_0 : 1.44 train loss_1 : 0.932 val loss_1 : -0.0638 train loss_2 : 0.1 val loss_2 : 1.44 train loss_3 : 1.2 val loss_3 : 5.46
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 240 train loss_0 : 0.1 val loss_0 : 1.42 train loss_1 : 0.932 val loss_1 : -0.0326 train loss_2 : 0.1 val loss_2 : 1.42 train loss_3 : 1.2 val loss_3 : 5.29
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 250 train loss_0 : 0.0986 val loss_0 : 1.43 train loss_1 : 0.932 val loss_1 : -0.0537 train loss_2 : 0.0986 val loss_2 : 1.43 train loss_3 : 1.19 val loss_3 : 5.47
# <br/>Waiting for W&B process to finish, PID 15638... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 1.71MB of 1.71MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>train/loss_0</td><td>██▇▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_1</td><td>▁▁▃▇▇███████████████████████████████████</td></tr><tr><td>train/loss_2</td><td>██▇▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_3</td><td>███▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/corr_mean</td><td>█▅▇▁</td></tr><tr><td>val/loss_0</td><td>▁▁▃▆▆█▇▆▆▇▆▆▆▆▆▆▇▇▆▆▆▆▅█▅▆▆▅▆▅▄▆▅▇▆▆▅▆▆▆</td></tr><tr><td>val/loss_1</td><td>▇█▃█▅▅▃▅▆▄▄▅▇▆▅▇▄▄▆▆▇▅▆▅▇▆▃▅▅▄▆▄▃▁▄▅▄▆▃▄</td></tr><tr><td>val/loss_2</td><td>▁▁▃▆▆█▇▆▆▇▆▆▆▆▆▆▇▇▆▆▆▆▅█▅▆▆▅▆▅▄▆▅▇▆▆▅▆▆▆</td></tr><tr><td>val/loss_3</td><td>████▃▂▂▂▂▂▂▂▂▁▂▁▁▁▁▂▁▁▁▁▂▁▁▂▁▂▂▁▁▁▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/loss_0</td><td>0.09856</td></tr><tr><td>train/loss_1</td><td>0.93222</td></tr><tr><td>train/loss_2</td><td>0.09856</td></tr><tr><td>train/loss_3</td><td>1.18524</td></tr><tr><td>val/loss_0</td><td>1.43478</td></tr><tr><td>val/loss_1</td><td>-0.05367</td></tr><tr><td>val/loss_2</td><td>1.43478</td></tr><tr><td>val/loss_3</td><td>5.47463</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 8 media file(s), 0 artifact file(s) and 2 other file(s)
# <br/>Synced <strong style="color:#cdcd00">pecan-square-207</strong>: <a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/246j6r6y" target="_blank">https://wandb.ai/koval_alvi/eeg_fmri/runs/246j6r6y</a><br/>
# Find logs at: <code>./wandb/run-20220314_143303-246j6r6y/logs</code><br/>
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/1lvhnmpa" target="_blank">neapolitan-flambee-236</a></strong> to <a href="https://wandb.ai/koval_alvi/eeg_fmri" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# {'n_electrodes': 63, 'n_freqs': 16, 'n_channels_out': 6, 'channels': [256, 128, 128, 128], 'kernel_sizes': [3, 3, 3], 'strides': [8, 4, 4], 'dilation': [1, 1, 1], 'decoder_reduce': 4, 'dataset_name': 'NODDI', 'new_fps': 100, 'freqs': array([ 2.        ,  2.59420132,  3.36494024,  4.3646662 ,  5.6614114 ,
#         7.34342046,  9.52515552, 12.3550855 , 16.02578954, 20.78706217,
#        26.96291204, 34.97361097, 45.36429384, 58.84205542, 76.32406886,
#        99.        ]), 'n_channels': 63, 'n_roi': 6, 'bold_delay': 5, 'to_many': True, 'random_subsample': True, 'sample_per_epoch': 2048, 'WINDOW_SIZE': 2048, 'optimizer': 'adam', 'lr': 0.0003, 'weight_decay': 0, 'batch_size': 16, 'preproc_type': 'dB_log', 'loss_function': 'mse', 'model_type': '1D_CNN_AE_wav2vec2'}
# AutoEncoder1D(
#   (spatial_reduce): ConvBlock(
#     (conv1d): Conv1d(1008, 256, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU()
#     (drop): Dropout(p=0.3, inplace=False)
#     (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (downsample_blocks): ModuleList(
#     (0): ConvBlock(
#       (conv1d): Conv1d(256, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.3, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (upsample_blocks): ModuleList(
#     (0): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (1): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (2): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.3, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#   )
#   (conv1x1_one): Conv1d(64, 6, kernel_size=(1,), stride=(1,), padding=same)
# )
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#        ConvBlock-1      [4, 256, 2048]         774,656         774,656
#        ConvBlock-2       [4, 128, 256]          98,560          98,560
#        ConvBlock-3        [4, 128, 64]          49,408          49,408
#        ConvBlock-4        [4, 128, 16]          49,408          49,408
#      UpConvBlock-5         [4, 32, 64]          12,352          12,352
#      UpConvBlock-6        [4, 32, 256]           3,136           3,136
#      UpConvBlock-7       [4, 64, 2048]           6,272           6,272
#           Conv1d-8        [4, 6, 2048]             390             390
# =======================================================================
# Total params: 994,182
# Trainable params: 994,182
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Starting Training of our model
# Number of samples 2048
# Size of batch: 16 Number batches 128
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Epoch 10 train loss_0 : 0.991 val loss_0 : 1.15 train loss_1 : -0.000847 val loss_1 : 0.0156 train loss_2 : 0.991 val loss_2 : 1.15 train loss_3 : 10.0 val loss_3 : 10.0
# ...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %% [markdown]
# #
