# %% [markdown]
# # Install libraries

# %%
import sys, os, json
import mne, sklearn, wandb
import numpy as np
import pandas as pd

from scipy.interpolate import interp1d
from nilearn import datasets, image, masking, plotting
from nilearn.input_data import NiftiLabelsMasker


# animation part
from IPython.display import HTML
import matplotlib
import matplotlib.pyplot as plt
# from celluloid import Camera   # it is convinient method to animate
from matplotlib import animation, rc
from matplotlib.animation import FuncAnimation


## torch libraries 
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader, Subset

from pytorch_model_summary import summary
# Out:
# /opt/conda/envs/myenv_torch/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
# %load_ext autoreload
# %autoreload 2
sys.path.insert(1, os.path.realpath(os.path.pardir))

from utils import get_datasets
from utils import preproc
from utils import torch_dataset
from utils import train_utils
from utils import inference
from utils.models_arch import autoencoder_new, autoencoder_v3_separable

# %% [markdown]
# # Set all hyperparameters
# - Cuda and GPU.
# - Parameters of dataset.
# - random seed( if necessary).

# %%
import random

torch.manual_seed(0)
random.seed(0)  # python operation seed
np.random.seed(0)

torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

print(torch.cuda.is_available(), torch.cuda.device_count())
torch.cuda.set_device(0)
# Out:
# True 4

# %%
config = dict(  
                dataset_name = 'CWL', # CWL
                new_fps=100, 
                freqs = np.logspace(np.log10(2), np.log10(99), 16), 
    
                n_channels = 30, # 30 
                n_roi = 6,
                
                bold_delay = 5,
                to_many = True,
                random_subsample = True,
                sample_per_epoch = 256, 
                WINDOW_SIZE = 512,
                    
                optimizer='adamW',
                lr=3e-4,
                weight_decay=1e-4, 
                batch_size=16, 
                
                preproc_type = 'dB_log',
                loss_function = 'mse', 
                model_type = 'CorrModel_AE1D_standard'
                )


hp_autoencoder = dict(n_electrodes=30,
                     n_freqs = 16,
                     n_channels_out=6,
                     corr_proj_size = 64,
                     channels = [128, 128, 128, 64], 
                     kernel_sizes=[5, 5, 3],
                     strides=[8, 8, 4], 
                     dilation=[1, 1, 1], 
                     decoder_reduce=4, 
                     window_size=config['WINDOW_SIZE'])


config = {**hp_autoencoder, **config}

params_train = {'batch_size': config['batch_size'],
                'shuffle': True,
                'num_workers': 0}

params_val = {'batch_size': config['batch_size'],
              'shuffle': False}

# %% [markdown]
# # Upload preprocessed dataset from np files.
# It should accelerate speed of experiments.

# %%
with open("../data/processed/labels_roi_6.json", 'r') as f:
    labels_roi = json.load(f)


if config['dataset_name']=='CWL':
    dataset_path = '../data/processed/CWL/trio1_100_hz_6_roi_2_99_freqs.npz'
    
elif config['dataset_name']=='NODDI':
    dataset_path = '../data/processed/NODDI/32_100_hz_6_roi_2_99_freqs.npz'
else:
    print('no such dataset')


# download data
data = np.load(dataset_path)

train_dataset_prep = (data['x_train'], data['y_train'])
test_dataset_prep = (data['x_test'], data['y_test'])


# apply time dealy corrected
train_dataset_prep = preproc.bold_time_delay_align(train_dataset_prep, 
                                                   config['new_fps'],
                                                   config['bold_delay'])
test_dataset_prep = preproc.bold_time_delay_align(test_dataset_prep, 
                                                  config['new_fps'],
                                                  config['bold_delay'])


print('Size of train dataset:', train_dataset_prep[0].shape, train_dataset_prep[1].shape)
print('Size of test dataset:', test_dataset_prep[0].shape, test_dataset_prep[1].shape)

# torch dataset creation 
torch_dataset_train = torch_dataset.CreateDataset_eeg_fmri(train_dataset_prep, 
                                                            random_sample=config['random_subsample'], 
                                                            sample_per_epoch=config['sample_per_epoch'], 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])

torch_dataset_test = torch_dataset.CreateDataset_eeg_fmri(test_dataset_prep, 
                                                            random_sample=False, 
                                                            sample_per_epoch=None, 
                                                            to_many=config['to_many'], 
                                                            window_size = config['WINDOW_SIZE'])

# because you do not have strid for val data. 
torch_dataset_test = Subset(torch_dataset_test, np.arange(len(torch_dataset_test))[::100])

# init dataloaders for training
train_loader = torch.utils.data.DataLoader(torch_dataset_train, **params_train)
val_loader = torch.utils.data.DataLoader(torch_dataset_test, **params_val)
# Out:
# Size of train dataset: (30, 16, 20690) (6, 20690)
# Size of test dataset: (30, 16, 5500) (6, 5500)

# %% [markdown]
# ## Model investigation

# %%
import torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader, Subset
from pytorch_model_summary import summary
import numpy as np




class ConvBlock(nn.Module):
    """
    Input is [batch, emb, time]
    simple conv block from wav2vec 2.0 
        - conv
        - layer norm by embedding axis
        - activation
    To do: 
        add res blocks.
    """
    def __init__(self, in_channels, out_channels, kernel_size, 
                 stride=1, dilation=1, p_conv_drop=0.1):
        super(ConvBlock, self).__init__()
        
        
        self.conv1d = nn.Conv1d(in_channels, out_channels, 
                                kernel_size=kernel_size, 
                                bias=False, 
                                padding='same')
        
        self.norm = nn.LayerNorm(out_channels)
        self.activation = nn.GELU()
        self.drop = nn.Dropout(p=p_conv_drop)
        
        self.downsample = nn.MaxPool1d(kernel_size=stride, stride=stride)


        
    def forward(self, x):
        """
        - conv 
        - norm 
        - activation
        - downsample 
        """
        x = self.conv1d(x)
        # norm by last axis.
        x = torch.transpose(x, -2, -1) 
        x = self.norm(x)
        x = torch.transpose(x, -2, -1) 
        
        x = self.activation(x)
        x = self.drop(x)
        
        x = self.downsample(x)
        
        return x


    
class UpConvBlock(nn.Module):
    def __init__(self, scale, **args):
        super(UpConvBlock, self).__init__()
        self.conv_block = ConvBlock(**args)
        self.upsample = nn.Upsample(scale_factor=scale, mode='linear', align_corners=False)

            
    def forward(self, x):
        
        x = self.conv_block(x)
        x = self.upsample(x)
        return x    
    
def extract_cross_corr(x, th=0.):
    """
    Calculate cross correllation between electrodes for each band 
    Return triu and reshape into one vector.
    
    Input:
        x.shape [batch, elec, n_freqs, time]
        th - threshold for removeing trash connectivity. 
    Returns: 
    x_cross_vec. shape [batch, n_freqs, elec*(elec-1)//2] 
    """
    batch, elec, n_freq, time = x.shape
        
    # cross corr features 
    x = x.transpose(1, 2)
    x = x.reshape(batch*n_freq, elec, -1)

    x_corrs = torch.stack([torch.corrcoef(x_) for x_ in x])
    x_corrs = torch.nan_to_num(x_corrs)
    x_corrs = x_corrs.reshape(batch, n_freq, elec, elec)

    x_corrs = torch.where(torch.abs(x_corrs)>th, x_corrs, torch.zeros_like(x_corrs))

    triu_idxs = torch.triu_indices(elec, elec, offset=1)
    x_corrs_vec =  x_corrs[..., triu_idxs[0], triu_idxs[1]]

    return x_corrs_vec  


    
    
class CrossCorrAutoEncoder1D(nn.Module):
    """
    This is implementation of AutoEncoder1D model for time serias regression
    
    decoder_reduce  -size of reducing parameter on decoder stage. We do not want use a lot of features here.
    
    corr_proj_size - 
    """
    def __init__(self,
                 window_size,
                 n_electrodes=30,
                 n_freqs = 16,
                 n_channels_out=21,
                 corr_proj_size = 128,
                 channels = [8, 16, 32, 32], 
                 kernel_sizes=[3, 3, 3],
                 strides=[4, 4, 4], 
                 dilation=[1, 1, 1], 
                 decoder_reduce=1,):
        
        super(CrossCorrAutoEncoder1D, self).__init__()
        

        self.n_electrodes = n_electrodes
        self.n_freqs = n_freqs
        self.n_inp_features = n_freqs*n_electrodes
        self.n_channels_out = n_channels_out
        self.window_size = window_size
        
        ## cross corr parameters. 
        cross_corr_vector_dim = int(n_freqs * n_electrodes*(n_electrodes-1)/2)
        self.project = nn.Sequential(nn.Conv1d(cross_corr_vector_dim, int(2*corr_proj_size), 1),
                                     nn.Dropout(p=0.25),
                                     nn.ReLU(),
                                     )
        
        
        # Encoder 
        self.model_depth = len(channels)-1
        channels = np.array(channels)
        
        self.spatial_reduce = ConvBlock(self.n_inp_features, channels[0], kernel_size=3)
        self.encoder = nn.Sequential(*[ConvBlock(channels[i], 
                                                 channels[i+1], 
                                                 kernel_sizes[i],
                                                 stride=strides[i], 
                                                 dilation=dilation[i], 
                                                 p_conv_drop=0.1) for i in range(self.model_depth)])
        ## Decoder 
        # Reduce number of channels ( do not touch last one. 
        channels[:-1] = channels[:-1]//decoder_reduce
        channels[-1] = channels[-1] + corr_proj_size
        print('Channels for decoder', channels)
        
        self.mapping = ConvBlock(channels[-1], channels[-1], 1)
        
        # channels
        self.decoder = nn.Sequential(*[UpConvBlock(scale=strides[i],
                                                   in_channels=channels[i+1],
                                                   out_channels=channels[i],
                                                   kernel_size=kernel_sizes[i], 
                                                   p_conv_drop=0.1) for i in range(self.model_depth-1, -1, -1)])
        
        
        self.conv1x1_one = nn.Conv1d(channels[0], 
                                     self.n_channels_out, 
                                     kernel_size=1,
                                     padding='same')

    def forward(self, x):
        """
        """
        batch, elec, n_freq, time = x.shape
        assert time == self.window_size, "PROBLEM with size "
        
        # cross corr features 
        x_corr_vec  = extract_cross_corr(x, th = 0.3)
        x_corr_vec = x_corr_vec.reshape(batch, -1, 1)
        
        x_proj = self.project(x_corr_vec) # [batch, corr_proj_size, 1]
        
        
        
        # wavelet features
        x = x.reshape(batch, -1, time)
        x = self.spatial_reduce(x)
        
        x = self.encoder(x)
        
        # aggregate features. 
        # x_proj_rep = x_proj.repeat(1, 1, x.shape[-1]) # copy to time axis.
        x_proj_rep = x_proj.reshape(batch, -1, 2)
        x = torch.cat([x, x_proj_rep], dim=1)
        x = self.mapping(x)
        
        x = self.decoder(x)
        x = self.conv1x1_one(x)
        
        return x

# %% [markdown]
# # Init Model, Loss, optimizers

# %%
model = CrossCorrAutoEncoder1D(**hp_autoencoder)

x = torch.zeros(4, 30, 16, 512)
print(model(x).shape)

print(summary(model, x, show_input=True))
# Out:
# Channels for decoder [ 32  32  32 128]
# torch.Size([4, 6, 512])
# -----------------------------------------------------------------------
#       Layer (type)         Input Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [4, 6960, 1]         891,008         891,008
#          Dropout-2         [4, 128, 1]               0               0
#             ReLU-3         [4, 128, 1]               0               0
#        ConvBlock-4       [4, 480, 512]         184,576         184,576
#        ConvBlock-5       [4, 128, 512]          82,176          82,176
#        ConvBlock-6        [4, 128, 64]          82,176          82,176
#        ConvBlock-7         [4, 128, 8]          24,704          24,704
#        ConvBlock-8         [4, 128, 2]          16,640          16,640
#      UpConvBlock-9         [4, 128, 2]          12,352          12,352
#     UpConvBlock-10          [4, 32, 8]           5,184           5,184
#     UpConvBlock-11         [4, 32, 64]           5,184           5,184
#          Conv1d-12        [4, 32, 512]             198             198
# =======================================================================
# Total params: 1,304,198
# Trainable params: 1,304,198
# Non-trainable params: 0
# -----------------------------------------------------------------------

# %% [markdown]
# # Model training

# %%
n_runs = 1

for i in range(n_runs):
    
    model = CrossCorrAutoEncoder1D(**hp_autoencoder)
    
    loss_func = train_utils.make_mse_loss()
    train_step = train_utils.train_step

    optimizer = optim.AdamW(model.parameters(), 
                       lr=config['lr'], 
                       weight_decay=config['weight_decay'])
    
    
    parameters = {
        'EPOCHS': 500,
        'model': model, 
        'train_loader': train_loader, 
        'val_loader': val_loader, 
        'loss_function': loss_func,
        'train_step': train_step,
        'optimizer': optimizer, 
        'device': 'cuda', 
        'raw_test_data': test_dataset_prep,
        'show_info': 5, 
        'num_losses': 5,
        'labels': labels_roi,
        'inference_function': inference.model_inference_function, 
        'to_many': config['to_many']
    }



    path_to_save_wandb = 'common/koval_alvi/Checkpoints/wandb_brain'
    
    
    with wandb.init(project="eeg_fmri", config=config, save_code=True):
        
        wandb.define_metric("val/corr_mean", summary="max")

        if i == 0: 
            exp_name = wandb.run.name
        
        wandb.run.name = exp_name +'_run_' + str(i)
        
        print(config)
        print(parameters['model'])
        print(summary(model, torch.zeros(4, config['n_channels'],
                                         len(config['freqs']), config['WINDOW_SIZE']), show_input=True))
        
        model = train_utils.wanb_train_regression(**parameters)
# Out:
# Channels for decoder [ 32  32  32 128]
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: koval_alvi (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/osdd8c3x" target="_blank">smart-serenity-247</a></strong> to <a href="https://wandb.ai/koval_alvi/eeg_fmri" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# {'n_electrodes': 30, 'n_freqs': 16, 'n_channels_out': 6, 'corr_proj_size': 64, 'channels': [128, 128, 128, 64], 'kernel_sizes': [5, 5, 3], 'strides': [8, 8, 4], 'dilation': [1, 1, 1], 'decoder_reduce': 4, 'window_size': 512, 'dataset_name': 'CWL', 'new_fps': 100, 'freqs': array([ 2.        ,  2.59420132,  3.36494024,  4.3646662 ,  5.6614114 ,
#         7.34342046,  9.52515552, 12.3550855 , 16.02578954, 20.78706217,
#        26.96291204, 34.97361097, 45.36429384, 58.84205542, 76.32406886,
#        99.        ]), 'n_channels': 30, 'n_roi': 6, 'bold_delay': 5, 'to_many': True, 'random_subsample': True, 'sample_per_epoch': 256, 'WINDOW_SIZE': 512, 'optimizer': 'adamW', 'lr': 0.0003, 'weight_decay': 0.0001, 'batch_size': 16, 'preproc_type': 'dB_log', 'loss_function': 'mse', 'model_type': 'CorrModel_AE1D_standard'}
# CrossCorrAutoEncoder1D(
#   (project): Sequential(
#     (0): Conv1d(6960, 128, kernel_size=(1,), stride=(1,))
#     (1): Dropout(p=0.25, inplace=False)
#     (2): ReLU()
#   )
#   (spatial_reduce): ConvBlock(
#     (conv1d): Conv1d(480, 128, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU()
#     (drop): Dropout(p=0.1, inplace=False)
#     (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (encoder): Sequential(
#     (0): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.1, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): ConvBlock(
#       (conv1d): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.1, inplace=False)
#       (downsample): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): ConvBlock(
#       (conv1d): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#       (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (activation): GELU()
#       (drop): Dropout(p=0.1, inplace=False)
#       (downsample): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (mapping): ConvBlock(
#     (conv1d): Conv1d(128, 128, kernel_size=(1,), stride=(1,), padding=same, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU()
#     (drop): Dropout(p=0.1, inplace=False)
#     (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.1, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=4.0, mode=linear)
#     )
#     (1): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.1, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#     (2): UpConvBlock(
#       (conv_block): ConvBlock(
#         (conv1d): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (activation): GELU()
#         (drop): Dropout(p=0.1, inplace=False)
#         (downsample): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#       )
#       (upsample): Upsample(scale_factor=8.0, mode=linear)
#     )
#   )
#   (conv1x1_one): Conv1d(32, 6, kernel_size=(1,), stride=(1,), padding=same)
# )
# -----------------------------------------------------------------------
#       Layer (type)         Input Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [4, 6960, 1]         891,008         891,008
#          Dropout-2         [4, 128, 1]               0               0
#             ReLU-3         [4, 128, 1]               0               0
#        ConvBlock-4       [4, 480, 512]         184,576         184,576
#        ConvBlock-5       [4, 128, 512]          82,176          82,176
#        ConvBlock-6        [4, 128, 64]          82,176          82,176
#        ConvBlock-7         [4, 128, 8]          24,704          24,704
#        ConvBlock-8         [4, 128, 2]          16,640          16,640
#      UpConvBlock-9         [4, 128, 2]          12,352          12,352
#     UpConvBlock-10          [4, 32, 8]           5,184           5,184
#     UpConvBlock-11         [4, 32, 64]           5,184           5,184
#          Conv1d-12        [4, 32, 512]             198             198
# =======================================================================
# Total params: 1,304,198
# Trainable params: 1,304,198
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Starting Training of our model
# Number of samples 256
# Size of batch: 16 Number batches 16
# ................................................................................
# Epoch 5 train loss_0 : 0.958 val loss_0 : 1.23 train loss_1 : 0.0362 val loss_1 : -0.0143
# ................................................................................
# Epoch 10 train loss_0 : 0.781 val loss_0 : 1.27 train loss_1 : 0.143 val loss_1 : -0.065
# ................................................................................
# Epoch 15 train loss_0 : 0.626 val loss_0 : 1.15 train loss_1 : 0.426 val loss_1 : 0.346
# ................................................................................
# Epoch 20 train loss_0 : 0.513 val loss_0 : 1.03 train loss_1 : 0.489 val loss_1 : 0.424
# ................................................................................
# Epoch 25 train loss_0 : 0.46 val loss_0 : 1.15 train loss_1 : 0.509 val loss_1 : 0.421
# ................................................................................
# Epoch 30 train loss_0 : 0.415 val loss_0 : 1.12 train loss_1 : 0.556 val loss_1 : 0.446
# ................................................................................
# Epoch 35 train loss_0 : 0.38 val loss_0 : 1.08 train loss_1 : 0.561 val loss_1 : 0.451
# ................................................................................
# Epoch 40 train loss_0 : 0.369 val loss_0 : 1.14 train loss_1 : 0.527 val loss_1 : 0.446
# ................................................................................
# Epoch 45 train loss_0 : 0.347 val loss_0 : 1.19 train loss_1 : 0.598 val loss_1 : 0.467
# ................................................................................
# Epoch 50 train loss_0 : 0.33 val loss_0 : 1.11 train loss_1 : 0.635 val loss_1 : 0.472
# ................................................................................
# Epoch 55 train loss_0 : 0.306 val loss_0 : 1.17 train loss_1 : 0.629 val loss_1 : 0.465
# ................................................................................
# Epoch 60 train loss_0 : 0.302 val loss_0 : 1.15 train loss_1 : 0.627 val loss_1 : 0.484
# ................................................................................
# Epoch 65 train loss_0 : 0.275 val loss_0 : 1.2 train loss_1 : 0.653 val loss_1 : 0.523
# ................................................................................
# Epoch 70 train loss_0 : 0.284 val loss_0 : 1.13 train loss_1 : 0.668 val loss_1 : 0.524
# ................................................................................
# Epoch 75 train loss_0 : 0.275 val loss_0 : 1.21 train loss_1 : 0.655 val loss_1 : 0.51
# ................................................................................
# Epoch 80 train loss_0 : 0.256 val loss_0 : 1.08 train loss_1 : 0.673 val loss_1 : 0.541
# ................................................................................
# Epoch 85 train loss_0 : 0.251 val loss_0 : 1.16 train loss_1 : 0.677 val loss_1 : 0.502
# ................................................................................
# Epoch 90 train loss_0 : 0.249 val loss_0 : 1.14 train loss_1 : 0.694 val loss_1 : 0.499
# ................................................................................
# Epoch 95 train loss_0 : 0.241 val loss_0 : 1.1 train loss_1 : 0.702 val loss_1 : 0.542
# ................................................................................
# Epoch 100 train loss_0 : 0.235 val loss_0 : 1.06 train loss_1 : 0.701 val loss_1 : 0.564
# ................................................................................
# Epoch 105 train loss_0 : 0.215 val loss_0 : 1.11 train loss_1 : 0.722 val loss_1 : 0.51
# ................................................................................
# Epoch 110 train loss_0 : 0.217 val loss_0 : 1.12 train loss_1 : 0.713 val loss_1 : 0.544
# ................................................................................
# Epoch 115 train loss_0 : 0.203 val loss_0 : 1.15 train loss_1 : 0.735 val loss_1 : 0.502
# ................................................................................
# Epoch 120 train loss_0 : 0.212 val loss_0 : 1.11 train loss_1 : 0.737 val loss_1 : 0.543
# ................................................................................
# Epoch 125 train loss_0 : 0.201 val loss_0 : 1.14 train loss_1 : 0.738 val loss_1 : 0.496
# ................................................................................
# Epoch 130 train loss_0 : 0.212 val loss_0 : 1.09 train loss_1 : 0.739 val loss_1 : 0.506
# ................................................................................
# Epoch 135 train loss_0 : 0.187 val loss_0 : 1.12 train loss_1 : 0.742 val loss_1 : 0.533
# ................................................................................
# Epoch 140 train loss_0 : 0.187 val loss_0 : 1.12 train loss_1 : 0.739 val loss_1 : 0.527
# ................................................................................
# Epoch 145 train loss_0 : 0.173 val loss_0 : 1.11 train loss_1 : 0.753 val loss_1 : 0.548
# ................................................................................
# Epoch 150 train loss_0 : 0.18 val loss_0 : 1.18 train loss_1 : 0.767 val loss_1 : 0.534
# ................................................................................
# Epoch 155 train loss_0 : 0.167 val loss_0 : 1.13 train loss_1 : 0.767 val loss_1 : 0.548
# ................................................................................
# Epoch 160 train loss_0 : 0.177 val loss_0 : 1.19 train loss_1 : 0.748 val loss_1 : 0.525
# ................................................................................
# Epoch 165 train loss_0 : 0.157 val loss_0 : 1.12 train loss_1 : 0.757 val loss_1 : 0.503
# ................................................................................
# Epoch 170 train loss_0 : 0.159 val loss_0 : 1.14 train loss_1 : 0.777 val loss_1 : 0.517
# ................................................................................
# Epoch 175 train loss_0 : 0.153 val loss_0 : 1.1 train loss_1 : 0.786 val loss_1 : 0.54
# ................................................................................
# Epoch 180 train loss_0 : 0.151 val loss_0 : 1.16 train loss_1 : 0.768 val loss_1 : 0.515
# ................................................................................
# Epoch 185 train loss_0 : 0.158 val loss_0 : 1.13 train loss_1 : 0.802 val loss_1 : 0.503
# ................................................................................
# Epoch 190 train loss_0 : 0.141 val loss_0 : 1.07 train loss_1 : 0.802 val loss_1 : 0.511
# ................................................................................
# Epoch 195 train loss_0 : 0.141 val loss_0 : 1.22 train loss_1 : 0.767 val loss_1 : 0.505
# ................................................................................
# Epoch 200 train loss_0 : 0.14 val loss_0 : 1.21 train loss_1 : 0.768 val loss_1 : 0.526
# ................................................................................
# Epoch 205 train loss_0 : 0.134 val loss_0 : 1.17 train loss_1 : 0.809 val loss_1 : 0.514
# ................................................................................
# Epoch 210 train loss_0 : 0.133 val loss_0 : 1.16 train loss_1 : 0.803 val loss_1 : 0.541
# ................................................................................
# Epoch 215 train loss_0 : 0.125 val loss_0 : 1.12 train loss_1 : 0.819 val loss_1 : 0.521
# ................................................................................
# Epoch 220 train loss_0 : 0.131 val loss_0 : 1.15 train loss_1 : 0.797 val loss_1 : 0.532
# ................................................................................
# Epoch 225 train loss_0 : 0.125 val loss_0 : 1.1 train loss_1 : 0.808 val loss_1 : 0.51
# ................................................................................
# Epoch 230 train loss_0 : 0.124 val loss_0 : 1.2 train loss_1 : 0.811 val loss_1 : 0.495
# ................................................................................
# Epoch 235 train loss_0 : 0.114 val loss_0 : 1.13 train loss_1 : 0.832 val loss_1 : 0.493
# ................................................................................
# Epoch 240 train loss_0 : 0.12 val loss_0 : 1.15 train loss_1 : 0.816 val loss_1 : 0.52
# ................................................................................
# Epoch 245 train loss_0 : 0.118 val loss_0 : 1.23 train loss_1 : 0.809 val loss_1 : 0.494
# ................................................................................
# Epoch 250 train loss_0 : 0.117 val loss_0 : 1.32 train loss_1 : 0.83 val loss_1 : 0.496
# ................................................................................
# Epoch 255 train loss_0 : 0.113 val loss_0 : 1.19 train loss_1 : 0.831 val loss_1 : 0.504
# ................................................................................
# Epoch 260 train loss_0 : 0.112 val loss_0 : 1.27 train loss_1 : 0.82 val loss_1 : 0.504
# ................................................................................
# Epoch 265 train loss_0 : 0.113 val loss_0 : 1.18 train loss_1 : 0.827 val loss_1 : 0.535
# ................................................................................
# Epoch 270 train loss_0 : 0.102 val loss_0 : 1.19 train loss_1 : 0.809 val loss_1 : 0.5
# ................................................................................
# Epoch 275 train loss_0 : 0.108 val loss_0 : 1.27 train loss_1 : 0.848 val loss_1 : 0.499
# ................................................................................
# Epoch 280 train loss_0 : 0.104 val loss_0 : 1.27 train loss_1 : 0.83 val loss_1 : 0.461
# ................................................................................
# Epoch 285 train loss_0 : 0.107 val loss_0 : 1.2 train loss_1 : 0.826 val loss_1 : 0.468
# ................................................................................
# Epoch 290 train loss_0 : 0.105 val loss_0 : 1.2 train loss_1 : 0.831 val loss_1 : 0.505
# ................................................................................
# Epoch 295 train loss_0 : 0.098 val loss_0 : 1.19 train loss_1 : 0.855 val loss_1 : 0.499
# ................................................................................
# Epoch 300 train loss_0 : 0.0998 val loss_0 : 1.19 train loss_1 : 0.818 val loss_1 : 0.438
# ................................................................................
# Epoch 305 train loss_0 : 0.0985 val loss_0 : 1.15 train loss_1 : 0.853 val loss_1 : 0.511
# ................................................................................
# Epoch 310 train loss_0 : 0.0976 val loss_0 : 1.21 train loss_1 : 0.844 val loss_1 : 0.479
# ................................................................................
# Epoch 315 train loss_0 : 0.0981 val loss_0 : 1.27 train loss_1 : 0.837 val loss_1 : 0.506
# ................................................................................
# Epoch 320 train loss_0 : 0.0946 val loss_0 : 1.37 train loss_1 : 0.846 val loss_1 : 0.479
# ................................................................................
# Epoch 325 train loss_0 : 0.0972 val loss_0 : 1.14 train loss_1 : 0.848 val loss_1 : 0.503
# ................................................................................
# Epoch 330 train loss_0 : 0.0938 val loss_0 : 1.22 train loss_1 : 0.839 val loss_1 : 0.48
# ................................................................................
# Epoch 335 train loss_0 : 0.0958 val loss_0 : 1.15 train loss_1 : 0.839 val loss_1 : 0.443
# ................................................................................
# Epoch 340 train loss_0 : 0.0873 val loss_0 : 1.24 train loss_1 : 0.841 val loss_1 : 0.479
# ................................................................................
# Epoch 345 train loss_0 : 0.0906 val loss_0 : 1.35 train loss_1 : 0.833 val loss_1 : 0.476
# ................................................................................
# Epoch 350 train loss_0 : 0.0886 val loss_0 : 1.2 train loss_1 : 0.858 val loss_1 : 0.404
# ................................................................................
# Epoch 355 train loss_0 : 0.094 val loss_0 : 1.31 train loss_1 : 0.85 val loss_1 : 0.489
# ................................................................................
# Epoch 360 train loss_0 : 0.0928 val loss_0 : 1.24 train loss_1 : 0.854 val loss_1 : 0.511
# ................................................................................
# Epoch 365 train loss_0 : 0.0877 val loss_0 : 1.26 train loss_1 : 0.859 val loss_1 : 0.479
# ................................................................................
# Epoch 370 train loss_0 : 0.0857 val loss_0 : 1.36 train loss_1 : 0.861 val loss_1 : 0.49
# ................................................................................
# Epoch 375 train loss_0 : 0.0855 val loss_0 : 1.34 train loss_1 : 0.862 val loss_1 : 0.483
# ................................................................................
# Epoch 380 train loss_0 : 0.0866 val loss_0 : 1.21 train loss_1 : 0.851 val loss_1 : 0.428
# ................................................................................
# Epoch 385 train loss_0 : 0.0887 val loss_0 : 1.31 train loss_1 : 0.863 val loss_1 : 0.468
# ................................................................................
# Epoch 390 train loss_0 : 0.0881 val loss_0 : 1.34 train loss_1 : 0.864 val loss_1 : 0.491
# ................................................................................
# Epoch 395 train loss_0 : 0.081 val loss_0 : 1.36 train loss_1 : 0.866 val loss_1 : 0.475
# ................................................................................
# Epoch 400 train loss_0 : 0.0878 val loss_0 : 1.3 train loss_1 : 0.862 val loss_1 : 0.49
# ................................................................................
# Epoch 405 train loss_0 : 0.0851 val loss_0 : 1.29 train loss_1 : 0.843 val loss_1 : 0.488
# ................................................................................
# Epoch 410 train loss_0 : 0.0811 val loss_0 : 1.37 train loss_1 : 0.854 val loss_1 : 0.479
# ................................................................................
# Epoch 415 train loss_0 : 0.084 val loss_0 : 1.32 train loss_1 : 0.865 val loss_1 : 0.457
# ................................................................................
# Epoch 420 train loss_0 : 0.0777 val loss_0 : 1.33 train loss_1 : 0.868 val loss_1 : 0.412
# ................................................................................
# Epoch 425 train loss_0 : 0.0788 val loss_0 : 1.29 train loss_1 : 0.868 val loss_1 : 0.446
# ................................................................................
# Epoch 430 train loss_0 : 0.0826 val loss_0 : 1.29 train loss_1 : 0.862 val loss_1 : 0.438
# ................................................................................
# Epoch 435 train loss_0 : 0.0789 val loss_0 : 1.37 train loss_1 : 0.868 val loss_1 : 0.44
# ................................................................................
# Epoch 440 train loss_0 : 0.0814 val loss_0 : 1.39 train loss_1 : 0.871 val loss_1 : 0.484
# ................................................................................
# Epoch 445 train loss_0 : 0.0813 val loss_0 : 1.4 train loss_1 : 0.873 val loss_1 : 0.426
# ................................................................................
# Epoch 450 train loss_0 : 0.0874 val loss_0 : 1.37 train loss_1 : 0.855 val loss_1 : 0.489
# ................................................................................
# Epoch 455 train loss_0 : 0.0768 val loss_0 : 1.39 train loss_1 : 0.862 val loss_1 : 0.449
# ................................................................................
# Epoch 460 train loss_0 : 0.0818 val loss_0 : 1.43 train loss_1 : 0.871 val loss_1 : 0.424
# ................................................................................
# Epoch 465 train loss_0 : 0.0793 val loss_0 : 1.43 train loss_1 : 0.873 val loss_1 : 0.442
# ................................................................................
# Epoch 470 train loss_0 : 0.0749 val loss_0 : 1.4 train loss_1 : 0.867 val loss_1 : 0.419
# ................................................................................
# Epoch 475 train loss_0 : 0.0798 val loss_0 : 1.45 train loss_1 : 0.867 val loss_1 : 0.468
# ................................................................................
# Epoch 480 train loss_0 : 0.0758 val loss_0 : 1.39 train loss_1 : 0.883 val loss_1 : 0.501
# ................................................................................
# Epoch 485 train loss_0 : 0.0771 val loss_0 : 1.32 train loss_1 : 0.86 val loss_1 : 0.469
# ................................................................................
# Epoch 490 train loss_0 : 0.0803 val loss_0 : 1.3 train loss_1 : 0.868 val loss_1 : 0.479
# ................................................................................
# Epoch 495 train loss_0 : 0.0751 val loss_0 : 1.3 train loss_1 : 0.886 val loss_1 : 0.455
# ................................................................................
# Epoch 500 train loss_0 : 0.0726 val loss_0 : 1.37 train loss_1 : 0.873 val loss_1 : 0.426
# <br/>Waiting for W&B process to finish, PID 22201... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 4.83MB of 4.83MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>train/loss_0</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_1</td><td>▁▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>val/corr_mean</td><td>▁▂▁▁▁▄▇▆▆▆▇▇▆█▇▇▆▆▇▇▇▇▇▇██▇█</td></tr><tr><td>val/loss_0</td><td>▃▃▁▂▃▂▁▁▄▂▃▂▂▁▃▃▄▃▄▃▃▄▅▆▆▇▄▆▄█▅▇▅▆▇██▆██</td></tr><tr><td>val/loss_1</td><td>▁▆▇▇▇▇█████████▇▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▅▇▇</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/loss_0</td><td>0.07262</td></tr><tr><td>train/loss_1</td><td>0.87282</td></tr><tr><td>val/loss_0</td><td>1.36539</td></tr><tr><td>val/loss_1</td><td>0.42608</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 56 media file(s), 0 artifact file(s) and 2 other file(s)
# <br/>Synced <strong style="color:#cdcd00">smart-serenity-247</strong>: <a href="https://wandb.ai/koval_alvi/eeg_fmri/runs/osdd8c3x" target="_blank">https://wandb.ai/koval_alvi/eeg_fmri/runs/osdd8c3x</a><br/>
# Find logs at: <code>./wandb/run-20220315_115712-osdd8c3x/logs</code><br/>

# %% [markdown]
# #
